# %% [markdown]
# # Preparing the Dataset

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
plt.style.use('ggplot')
import seaborn as sns

# %%
# Kept the original dataset
listingsNYC = pd.read_csv('listings.csv', dtype=object)
listingsNYC
# Out:
#                        id                                               name  \
# 0                    5136           Spacious Brooklyn Duplex, Patio + Garden
# 1                    5203                 Cozy Clean Guest Room - Family Apt
# 2                    5121                                    BlissArtsSpace!
# 3                    5178                   Large Furnished Room Near B'way
# 4                    2595                              Skylit Midtown Castle
# ...                   ...                                                ...
# 41528  771962449581256963                                Romántico y natural
# 41529  771967712456918474                          Sunset Park Studio Sublet
# 41530  771971759808918693     9B5B Townhouse w/ Elevator &  Private Entrance
# 41531  771971822371481471  Huge 9B5B Townhouse w Elevator &  Private Entr...
# 41532  771975190766692224           Lovely  Big Studio for Rental Bronx City
#
# ...

# %%
# Dropping all of the columns which we will not use
# listingsNYC= listingsNYC.drop(['last_review','license','latitude','longitude','host_name'], axis=1)

# Dropping all rows with any 'Nan' values in them
# listingsNYC.dropna(axis=0, how='any', inplace=True)
data_types_dict = {
    'price':'int64', 
    'minimum_nights':'int64', 
    'host_id':str,
    'number_of_reviews':'int64',
    'reviews_per_month':float,
    'calculated_host_listings_count':'int64',
    'availability_365':'int64',
    'number_of_reviews_ltm':'int64'}

#changing all the datatype to their respective types that we can work with
listingsNYC = listingsNYC.astype(data_types_dict)

# creating a price per stay (ppn) column with the price and minimim nights columns and rounding to 2 decimal places. 
# This is a float dtype 
listingsNYC['pps'] = (listingsNYC['price'] * listingsNYC['minimum_nights']).round(2)
listingsNYC['neighbourhood'].unique().shape[0]
listingsNYC.describe()
# Out:
#               price  minimum_nights  number_of_reviews  reviews_per_month  \
# count  41533.000000    41533.000000       41533.000000       32140.000000
# mean     221.978282       18.592204          26.204994           1.279287
# std      919.502236       30.699921          56.178847           1.935098
# min        0.000000        1.000000           0.000000           0.010000
# 25%       80.000000        2.000000           1.000000           0.140000
# 50%      131.000000       10.000000           5.000000           0.580000
# 75%      220.000000       30.000000          25.000000           1.880000
# max    98159.000000     1250.000000        1666.000000         102.980000
#
#        calculated_host_listings_count  availability_365  \
# count                    41533.000000      41533.000000
# mean                        20.626803        143.287771
# std                         68.874393        144.279510
# min                          1.000000          0.000000
# ...

# %%
listing_count_less_than_300 = listingsNYC.copy(deep=True)
listing_count_less_than_300 = listing_count_less_than_300[listing_count_less_than_300['calculated_host_listings_count']<300]

# %%
sns.boxplot(x = 'neighbourhood_group', y = 'calculated_host_listings_count', data = listingsNYC)
# Out:
# <AxesSubplot:xlabel='neighbourhood_group', ylabel='calculated_host_listings_count'>

# %%
sns.boxplot(x = 'neighbourhood_group', y = 'calculated_host_listings_count', data = listing_count_less_than_300)
# Out:
# <AxesSubplot:xlabel='neighbourhood_group', ylabel='calculated_host_listings_count'>

# %%
listing_price_less_than_10k = listingsNYC.copy(deep=True)
listing_price_less_than_10k = listing_price_less_than_10k[listing_price_less_than_10k['price']<8000]

# %%
sns.scatterplot(x='calculated_host_listings_count',y='price', hue='neighbourhood_group', data=listingsNYC)
# Out:
# <AxesSubplot:xlabel='calculated_host_listings_count', ylabel='price'>

# %%
sns.scatterplot(x='calculated_host_listings_count',y='price', hue='neighbourhood_group', data=listing_price_less_than_10k)

# %%
brooklyn = listing_price_less_than_10k[listing_price_less_than_10k['neighbourhood_group']=='Brooklyn']
manhattan = listing_price_less_than_10k[listing_price_less_than_10k['neighbourhood_group']=='Manhattan']
queens = listing_price_less_than_10k[listing_price_less_than_10k['neighbourhood_group']=='Queens']
bronx = listing_price_less_than_10k[listing_price_less_than_10k['neighbourhood_group']=='Bronx']
staten_island = listing_price_less_than_10k[listing_price_less_than_10k['neighbourhood_group']=='Staten Island']

# %%
sns.scatterplot(x='calculated_host_listings_count',y='price', data=brooklyn)
# Out:
# <AxesSubplot:xlabel='calculated_host_listings_count', ylabel='price'>

# %%
sns.scatterplot(x='calculated_host_listings_count',y='price', data=manhattan)
# Out:
# <AxesSubplot:xlabel='calculated_host_listings_count', ylabel='price'>

# %%
sns.scatterplot(x='calculated_host_listings_count',y='price', data=queens)
# Out:
# <AxesSubplot:xlabel='calculated_host_listings_count', ylabel='price'>

# %%
sns.scatterplot(x='calculated_host_listings_count',y='price', data=bronx)
# Out:
# <AxesSubplot:xlabel='calculated_host_listings_count', ylabel='price'>

# %%
sns.scatterplot(x='calculated_host_listings_count',y='price', data=staten_island)
# Out:
# <AxesSubplot:xlabel='calculated_host_listings_count', ylabel='price'>

# %%
listingsNYC['calculated_host_listings_count'].describe()
# Out:
# count    41533.000000
# mean        20.626803
# std         68.874393
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          4.000000
# max        487.000000
# Name: calculated_host_listings_count, dtype: float64
