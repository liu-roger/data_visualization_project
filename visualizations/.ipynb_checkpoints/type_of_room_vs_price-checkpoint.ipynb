# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
plt.style.use('ggplot')
import seaborn as sns

# %% [markdown]
# - The link where the data was downloaded is: http://insideairbnb.com/get-the-data/.
# - This dataset is specifically the listings in NYC.
# - The data columns can be explained when clicking on this link https://docs.google.com/spreadsheets/d/1iWCNJcSutYqpULSQHlNyGInUvHg2BoUGoNRIGa6Szc4/edit?usp=sharing.
# - Data used in this project was scraped on December 15, 2022.

# %% [markdown]
# # Loading and Preparing Datasets

# %%
# Kept the original dataset 
listingsNYC = pd.read_csv('listings.csv', dtype=object)
listingsNYC
# Out:
#                        id                                               name  \
# 0                    5136           Spacious Brooklyn Duplex, Patio + Garden
# 1                    5203                 Cozy Clean Guest Room - Family Apt
# 2                    5121                                    BlissArtsSpace!
# 3                    5178                   Large Furnished Room Near B'way
# 4                    2595                              Skylit Midtown Castle
# ...                   ...                                                ...
# 41528  771962449581256963                                Romántico y natural
# 41529  771967712456918474                          Sunset Park Studio Sublet
# 41530  771971759808918693     9B5B Townhouse w/ Elevator &  Private Entrance
# 41531  771971822371481471  Huge 9B5B Townhouse w Elevator &  Private Entr...
# 41532  771975190766692224           Lovely  Big Studio for Rental Bronx City
#
#          host_id      host_name neighbourhood_group       neighbourhood  \
# 0           7378        Rebecca            Brooklyn         Sunset Park
# 1           7490      MaryEllen           Manhattan     Upper West Side
# 2           7356          Garon            Brooklyn  Bedford-Stuyvesant
# 3           8967       Shunichi           Manhattan             Midtown
# 4           2845       Jennifer           Manhattan             Midtown
# ...          ...            ...                 ...                 ...
# 41528  421601513    Juan Carlos           Manhattan  Washington Heights
# 41529     326495  Laura Adriana            Brooklyn         Sunset Park
# 41530  316920152        Allison           Manhattan         Murray Hill
# 41531  484979380        Natasha           Manhattan         Murray Hill
# 41532  426540801           Abul               Bronx           Unionport
#
#                 latitude           longitude        room_type price  \
# 0               40.66265           -73.99454  Entire home/apt   275
# 1                40.8038           -73.96751     Private room    75
# 2               40.68535           -73.95512     Private room    60
# 3               40.76457           -73.98317     Private room    68
# 4               40.75356           -73.98559  Entire home/apt   175
# ...                  ...                 ...              ...   ...
# 41528  40.84727072881559  -73.94341916084775     Private room    80
# 41529  40.63832893587064  -74.01671019409663  Entire home/apt    42
# 41530  40.74690169639175  -73.97826030246593  Entire home/apt  3888
# 41531  40.74959584319043  -73.98079769535242  Entire home/apt  3888
# 41532  40.83282398123486  -73.85237137116201  Entire home/apt    80
#
#       minimum_nights number_of_reviews last_review reviews_per_month  \
# 0                 21                 3  2022-08-10              0.03
# 1                  2               118  2017-07-21              0.73
# 2                 30                50  2019-12-02              0.30
# 3                  2               559  2022-11-20              3.38
# 4                 30                49  2022-06-21              0.31
# ...              ...               ...         ...               ...
# 41528              5                 0         NaN               NaN
# 41529             30                 0         NaN               NaN
# 41530              2                 0         NaN               NaN
# 41531              2                 0         NaN               NaN
# 41532              3                 0         NaN               NaN
#
#       calculated_host_listings_count availability_365 number_of_reviews_ltm  \
# 0                                  1              267                     1
# 1                                  1                0                     0
# 2                                  2              322                     0
# 3                                  1               79                    50
# 4                                  3              365                     1
# ...                              ...              ...                   ...
# 41528                              3              358                     0
# 41529                              3               89                     0
# 41530                              8              365                     0
# 41531                              2              364                     0
# 41532                              2              365                     0
#
#       license
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 41528     NaN
# 41529     NaN
# 41530     NaN
# 41531     NaN
# 41532     NaN
#
# [41533 rows x 18 columns]

# %% [markdown]
# ### Changing dtypes for the columns

# %% [markdown]
# # Preparing Datasets

# %%
# Kept the original dataset
# listingsNYC = pd.read_csv('listings.csv', dtype=object)

# Dropping all of the columns which we will not use
# listingsNYC= listingsNYC.drop(['last_review','license','latitude','longitude','host_name'], axis=1)

# Dropping all rows with any 'Nan' values in them
# listingsNYC.dropna(axis=0, how='any', inplace=True)
data_types_dict = {
    'price':'int64', 
    'minimum_nights':'int64', 
    'host_id':str,
    'number_of_reviews':'int64',
    'reviews_per_month':float,
    'calculated_host_listings_count':'int64',
    'availability_365':'int64',
    'number_of_reviews_ltm':'int64'}

#changing all the datatype to their respective types that we can work with
listingsNYC = listingsNYC.astype(data_types_dict)

# creating a price per stay (ppn) column with the price and minimim nights columns and rounding to 2 decimal places. 
# This is a float dtype 
listingsNYC['pps'] = (listingsNYC['price'] * listingsNYC['minimum_nights']).round(2)
listingsNYC_outlier=listingsNYC.copy(deep=True)
listingsNYC
# Out:
#                        id                                               name  \
# 0                    5136           Spacious Brooklyn Duplex, Patio + Garden
# 1                    5203                 Cozy Clean Guest Room - Family Apt
# 2                    5121                                    BlissArtsSpace!
# 3                    5178                   Large Furnished Room Near B'way
# 4                    2595                              Skylit Midtown Castle
# ...                   ...                                                ...
# 41528  771962449581256963                                Romántico y natural
# 41529  771967712456918474                          Sunset Park Studio Sublet
# 41530  771971759808918693     9B5B Townhouse w/ Elevator &  Private Entrance
# 41531  771971822371481471  Huge 9B5B Townhouse w Elevator &  Private Entr...
# 41532  771975190766692224           Lovely  Big Studio for Rental Bronx City
#
#          host_id      host_name neighbourhood_group       neighbourhood  \
# 0           7378        Rebecca            Brooklyn         Sunset Park
# 1           7490      MaryEllen           Manhattan     Upper West Side
# 2           7356          Garon            Brooklyn  Bedford-Stuyvesant
# 3           8967       Shunichi           Manhattan             Midtown
# 4           2845       Jennifer           Manhattan             Midtown
# ...          ...            ...                 ...                 ...
# 41528  421601513    Juan Carlos           Manhattan  Washington Heights
# 41529     326495  Laura Adriana            Brooklyn         Sunset Park
# 41530  316920152        Allison           Manhattan         Murray Hill
# 41531  484979380        Natasha           Manhattan         Murray Hill
# 41532  426540801           Abul               Bronx           Unionport
#
#                 latitude           longitude        room_type  price  \
# 0               40.66265           -73.99454  Entire home/apt    275
# 1                40.8038           -73.96751     Private room     75
# 2               40.68535           -73.95512     Private room     60
# 3               40.76457           -73.98317     Private room     68
# 4               40.75356           -73.98559  Entire home/apt    175
# ...                  ...                 ...              ...    ...
# 41528  40.84727072881559  -73.94341916084775     Private room     80
# 41529  40.63832893587064  -74.01671019409663  Entire home/apt     42
# 41530  40.74690169639175  -73.97826030246593  Entire home/apt   3888
# 41531  40.74959584319043  -73.98079769535242  Entire home/apt   3888
# 41532  40.83282398123486  -73.85237137116201  Entire home/apt     80
#
#        minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0                  21                  3  2022-08-10               0.03
# 1                   2                118  2017-07-21               0.73
# 2                  30                 50  2019-12-02               0.30
# 3                   2                559  2022-11-20               3.38
# 4                  30                 49  2022-06-21               0.31
# ...               ...                ...         ...                ...
# 41528               5                  0         NaN                NaN
# 41529              30                  0         NaN                NaN
# 41530               2                  0         NaN                NaN
# 41531               2                  0         NaN                NaN
# 41532               3                  0         NaN                NaN
#
#        calculated_host_listings_count  availability_365  \
# 0                                   1               267
# 1                                   1                 0
# 2                                   2               322
# 3                                   1                79
# 4                                   3               365
# ...                               ...               ...
# 41528                               3               358
# 41529                               3                89
# 41530                               8               365
# 41531                               2               364
# 41532                               2               365
#
#        number_of_reviews_ltm license   pps
# 0                          1     NaN  5775
# 1                          0     NaN   150
# 2                          0     NaN  1800
# 3                         50     NaN   136
# 4                          1     NaN  5250
# ...                      ...     ...   ...
# 41528                      0     NaN   400
# 41529                      0     NaN  1260
# 41530                      0     NaN  7776
# 41531                      0     NaN  7776
# 41532                      0     NaN   240
#
# [41533 rows x 19 columns]

# %% [markdown]
# ### Removing Zeros

# %%
# check for outliers 
describe_df = listingsNYC.describe()
describe_df
# Out:
#               price  minimum_nights  number_of_reviews  reviews_per_month  \
# count  41533.000000    41533.000000       41533.000000       32140.000000
# mean     221.978282       18.592204          26.204994           1.279287
# std      919.502236       30.699921          56.178847           1.935098
# min        0.000000        1.000000           0.000000           0.010000
# 25%       80.000000        2.000000           1.000000           0.140000
# 50%      131.000000       10.000000           5.000000           0.580000
# 75%      220.000000       30.000000          25.000000           1.880000
# max    98159.000000     1250.000000        1666.000000         102.980000
#
#        calculated_host_listings_count  availability_365  \
# count                    41533.000000      41533.000000
# mean                        20.626803        143.287771
# std                         68.874393        144.279510
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000         87.000000
# 75%                          4.000000        312.000000
# max                        487.000000        365.000000
#
#        number_of_reviews_ltm           pps
# count           41533.000000  4.153300e+04
# mean                7.983700  3.313718e+03
# std                18.563894  1.916310e+04
# min                 0.000000  0.000000e+00
# 25%                 0.000000  3.480000e+02
# 50%                 1.000000  1.332000e+03
# 75%                 8.000000  3.600000e+03
# max               992.000000  2.253600e+06

# %% [markdown]
# ### Dropping rows with a price or pps of 0

# %%
listingsNYC = listingsNYC[(listingsNYC['price'] != 0)]
listingsNYC.describe()
# Out:
#               price  minimum_nights  number_of_reviews  reviews_per_month  \
# count  41503.000000    41503.000000       41503.000000       32124.000000
# mean     222.138737       18.599330          26.199431           1.278696
# std      919.815135       30.707935          56.166678           1.933835
# min       10.000000        1.000000           0.000000           0.010000
# 25%       80.000000        2.000000           1.000000           0.140000
# 50%      131.000000       10.000000           5.000000           0.580000
# 75%      220.000000       30.000000          25.000000           1.880000
# max    98159.000000     1250.000000        1666.000000         102.980000
#
#        calculated_host_listings_count  availability_365  \
# count                    41503.000000      41503.000000
# mean                        20.640797        143.391345
# std                         68.897303        144.280187
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000         87.000000
# 75%                          4.000000        312.000000
# max                        487.000000        365.000000
#
#        number_of_reviews_ltm           pps
# count           41503.000000  4.150300e+04
# mean                7.981471  3.316113e+03
# std                18.560462  1.916982e+04
# min                 0.000000  1.900000e+01
# 25%                 0.000000  3.500000e+02
# 50%                 1.000000  1.341000e+03
# 75%                 8.000000  3.600000e+03
# max               992.000000  2.253600e+06

# %% [markdown]
# # Visualizations

# %%
sns.boxplot(x = 'room_type', y = 'price', data = listingsNYC, color='blue')
# Out:
# <AxesSubplot:xlabel='room_type', ylabel='price'>

# %%
sns.jointplot(x = listingsNYC['room_type'],y = listingsNYC['price'], color='blue')

# %%
price_no_outlier = listingsNYC.loc[(listingsNYC['price'] - listingsNYC['price'].mean()).abs() / listingsNYC['price'].std() < 1]
price_no_outlier.shape
# Out:
# (40843, 19)

# %%
sns.jointplot(x = price_no_outlier['room_type'],y = price_no_outlier['price'], color='blue')

# %%
sns.boxplot(x = price_no_outlier['room_type'],y = price_no_outlier['price'])
# Out:
# <AxesSubplot:xlabel='room_type', ylabel='price'>

# %%
# finding the mean price and price per night of each room_type
room_type_groups = price_no_outlier.groupby('room_type')
grouped_by_room_type = room_type_groups[['price','pps']].mean()
grouped_by_room_type=grouped_by_room_type.reset_index()
grouped_by_room_type
# Out:
#          room_type       price          pps
# 0  Entire home/apt  224.046411  3742.108825
# 1       Hotel room  443.026667  3352.913333
# 2     Private room  114.591145  1503.619819
# 3      Shared room   97.220952  1687.523810

# %%
plt.bar(grouped_by_room_type['room_type'], grouped_by_room_type['price'], color='blue')
plt.xlabel('Room Type')
plt.ylabel('Average Price')
plt.title('Barplot of Average Price for each Room Type (No Outliers)', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Barplot of Average Price for each Room Type (No Outliers)')

# %%
room_type_groups_outliers = listingsNYC_outlier.groupby('room_type')
grouped_by_room_type_outliers = room_type_groups_outliers[['price','pps']].mean()
grouped_by_room_type_outliers=grouped_by_room_type_outliers.reset_index()
grouped_by_room_type_outliers
# Out:
#          room_type       price          pps
# 0  Entire home/apt  263.442404  4365.993412
# 1       Hotel room  416.164894  3275.771277
# 2     Private room  166.102042  1901.055302
# 3      Shared room  135.400376  2697.165414

# %%
plt.bar(grouped_by_room_type_outliers['room_type'], grouped_by_room_type_outliers['price'], color='blue')
plt.xlabel('Room Type')
plt.ylabel('Average Price')
plt.title('Barplot of Average Price for each Room Type', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Barplot of Average Price for each Room Type')
