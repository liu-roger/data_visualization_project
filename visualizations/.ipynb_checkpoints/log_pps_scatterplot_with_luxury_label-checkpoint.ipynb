# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
plt.style.use('ggplot')
import seaborn as sns
from scipy.signal import find_peaks

# %% [markdown]
# - The link where the data was downloaded is: http://insideairbnb.com/get-the-data/.
# - This dataset is specifically the listings in NYC.
# - The data columns can be explained when clicking on this link https://docs.google.com/spreadsheets/d/1iWCNJcSutYqpULSQHlNyGInUvHg2BoUGoNRIGa6Szc4/edit?usp=sharing.
# - Data used in this project was scraped on December 15, 2022.

# %% [markdown]
# # Loading and Preparing Datasets

# %%
# Kept the original dataset
listingsNYC = pd.read_csv('listings.csv', dtype=object)

# Dropping all of the columns which we will not use
listingsNYC= listingsNYC.drop(['last_review','license','latitude','longitude','host_name'], axis=1)

# Dropping all rows with any 'Nan' values in them
listingsNYC.dropna(axis=0, how='any', inplace=True)
data_types_dict = {
    'price':'int64', 
    'minimum_nights':'int64', 
    'host_id':str,
    'number_of_reviews':'int64',
    'reviews_per_month':float,
    'calculated_host_listings_count':'int64',
    'availability_365':'int64',
    'number_of_reviews_ltm':'int64'}

#changing all the datatype to their respective types that we can work with
listingsNYC = listingsNYC.astype(data_types_dict)

# creating a price per stay (ppn) column with the price and minimim nights columns and rounding to 2 decimal places. 
# This is a float dtype 
listingsNYC['pps'] = (listingsNYC['price'] * listingsNYC['minimum_nights']).round(2)
listingsNYC['neighbourhood'].unique().shape[0]
listingsNYC
# Out:
#                        id                                          name  \
# 0                    5136      Spacious Brooklyn Duplex, Patio + Garden
# 1                    5203            Cozy Clean Guest Room - Family Apt
# 2                    5121                               BlissArtsSpace!
# 3                    5178              Large Furnished Room Near B'way
# 4                    2595                         Skylit Midtown Castle
# ...                   ...                                           ...
# 41139  769580756557673403       Cozy 1 bedroom with 2 full beds ROOM #2
# 41160  769612968972941927                 Comfortable 1 bedroom ROOM #3
# 41175  770593748958588679  Luxury Brooklyn apt. | 10 mins away from JFK
# 41218  769850569510129629                 Private Bed Manhattan 20 Mins
# 41431  773290288588713925              Modern Luxury- Chelsea Townhouse
#
#          host_id neighbourhood_group       neighbourhood        room_type  \
# 0           7378            Brooklyn         Sunset Park  Entire home/apt
# 1           7490           Manhattan     Upper West Side     Private room
# 2           7356            Brooklyn  Bedford-Stuyvesant     Private room
# 3           8967           Manhattan             Midtown     Private room
# 4           2845           Manhattan             Midtown  Entire home/apt
# ...          ...                 ...                 ...              ...
# 41139  162927656              Queens             Jamaica      Shared room
# 41160  162927656              Queens             Jamaica      Shared room
# 41175  489532090            Brooklyn       East New York  Entire home/apt
# 41218  324722741              Queens            Woodside     Private room
# 41431  371921352           Manhattan             Chelsea  Entire home/apt
#
#        price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0        275              21                  3               0.03
# 1         75               2                118               0.73
# 2         60              30                 50               0.30
# 3         68               2                559               3.38
# 4        175              30                 49               0.31
# ...      ...             ...                ...                ...
# 41139     99               1                  1               1.00
# 41160     91               1                  1               1.00
# 41175    145               1                  2               2.00
# 41218     50               1                  1               1.00
# 41431   2000               3                  1               1.00
#
#        calculated_host_listings_count  availability_365  \
# 0                                   1               267
# 1                                   1                 0
# 2                                   2               322
# 3                                   1                79
# 4                                   3               365
# ...                               ...               ...
# 41139                               7               174
# 41160                               7               174
# 41175                               1               351
# 41218                               1               240
# 41431                               1               338
#
#        number_of_reviews_ltm   pps
# 0                          1  5775
# 1                          0   150
# 2                          0  1800
# 3                         50   136
# 4                          1  5250
# ...                      ...   ...
# 41139                      1    99
# 41160                      1    91
# 41175                      2   145
# 41218                      1    50
# 41431                      1  6000
#
# [32134 rows x 14 columns]

# %% [markdown]
# ### Adding Price Per Stay (pps) column

# %%
# creating a price per stay (ppn) column with the price and minimim nights columns and rounding to 2 decimal places. 
# This is a float dtype 
listingsNYC['pps'] = (listingsNYC['price'] * listingsNYC['minimum_nights']).round(2)
listingsNYC['neighbourhood'].unique().shape[0]
# Out:
# 221

# %% [markdown]
# ### Removing Outliers

# %%
# check for outliers 
describe_df = listingsNYC.describe()
describe_df
# Out:
#               price  minimum_nights  number_of_reviews  reviews_per_month  \
# count  32134.000000    32134.000000       32134.000000       32134.000000
# mean     196.275223       16.139354          33.867866           1.279502
# std      831.541622       28.483042          61.803678           1.935213
# min        0.000000        1.000000           1.000000           0.010000
# 25%       80.000000        2.000000           3.000000           0.140000
# 50%      130.000000        5.000000          10.000000           0.580000
# 75%      208.000000       30.000000          36.000000           1.880000
# max    98159.000000     1250.000000        1666.000000         102.980000
#
#        calculated_host_listings_count  availability_365  \
# count                    32134.000000      32134.000000
# mean                        10.636958        142.513506
# std                         38.325794        141.416457
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000         89.000000
# 75%                          3.000000        306.000000
# max                        487.000000        365.000000
#
#        number_of_reviews_ltm           pps
# count           32134.000000  3.213400e+04
# mean               10.318883  2.685699e+03
# std                20.526149  1.573199e+04
# min                 0.000000  0.000000e+00
# 25%                 0.000000  2.980000e+02
# 50%                 2.000000  1.028000e+03
# 75%                13.000000  3.000000e+03
# max               992.000000  2.253600e+06

# %% [markdown]
# ### Dropping rows with a price or pps of 0

# %%
listingsNYC = listingsNYC[(listingsNYC['price'] != 0)]
listingsNYC.loc[:,'log_price']=np.log(listingsNYC['price'])
listingsNYC.loc[:,'log_pps']=np.log(listingsNYC['pps'])
listingsNYC.describe()
# Out:
# C:\Users\Roger\AppData\Local\Temp\ipykernel_7924\4226997428.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   listingsNYC.loc[:,'log_price']=np.log(listingsNYC['price'])
# C:\Users\Roger\AppData\Local\Temp\ipykernel_7924\4226997428.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   listingsNYC.loc[:,'log_pps']=np.log(listingsNYC['pps'])
#               price  minimum_nights  number_of_reviews  reviews_per_month  \
# count  32118.000000    32118.000000       32118.000000       32118.000000
# mean     196.373000       16.146896          33.853073           1.278912
# std      831.737182       28.488131          61.785419           1.933950
# min       10.000000        1.000000           1.000000           0.010000
# 25%       80.000000        2.000000           3.000000           0.140000
# 50%      130.000000        5.000000          10.000000           0.580000
# 75%      208.750000       30.000000          36.000000           1.880000
# max    98159.000000     1250.000000        1666.000000         102.980000
#
#        calculated_host_listings_count  availability_365  \
# count                    32118.000000      32118.000000
# mean                        10.641509        142.584501
# std                         38.334772        141.415890
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000         89.000000
# 75%                          3.000000        306.000000
# max                        487.000000        365.000000
#
#        number_of_reviews_ltm           pps     log_price       log_pps
# count           32118.000000  3.211800e+04  32118.000000  32118.000000
# mean               10.313687  2.687037e+03      4.909107      6.841976
# std                20.520742  1.573580e+04      0.739517      1.459360
# min                 0.000000  1.900000e+01      2.302585      2.944439
# 25%                 0.000000  2.980000e+02      4.382027      5.697093
# 50%                 2.000000  1.029000e+03      4.867534      6.936343
# 75%                13.000000  3.000000e+03      5.341135      8.006368
# max               992.000000  2.253600e+06     11.494344     14.628039

# %% [markdown]
# # Visualizations

# %%
plt.hist((listingsNYC['pps']), bins = 15, color='blue')
plt.xlabel('Price Per Night of Airbnb (USD)')
plt.ylabel('Frequency')
plt.title('Histogram of Price per Night (pps)', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Histogram of Price per Night (pps)')

# %%
plt.hist((listingsNYC['log_pps']), bins = 15, color='blue')
plt.xlabel('Log Price Per Night of Airbnb (USD)')
plt.ylabel('Frequency')
plt.title('Histogram of Log Price per Night (pps)', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Histogram of Log Price per Night (pps)')

# %%
sns.displot((listingsNYC['log_pps']), kde=True, color='blue')

# %%
kde = sns.kdeplot(listingsNYC['log_pps'])

kde_values = -kde.get_lines()[0].get_ydata()
minima, _ = find_peaks(kde_values)

x_values = kde.get_lines()[0].get_xdata()[minima]
x_values
# Out:
# array([ 6.69864257, 12.28697826, 13.25048441, 14.08552307])

# %%
x_values = sns.kdeplot(listingsNYC['log_pps']).get_lines()[0].get_xdata()[minima]
print('Local minima:', minima)
print('Values:', kde[minima])
# Out:
# Local minima: [ 67 154 169 182]
# Values: [-1.75411093e-01 -5.52526947e-04 -4.70829675e-05 -1.20333053e-06]

# %%
# add a dummy variable to 'classify' the listings into a 'luxury' and 'budget'
listingsNYC.loc['is_budget'] = listingsNYC['log_pps'].apply(lambda x: x < 6.69864257)
listingsNYC['is_luxury'] = listingsNYC['log_pps'].apply(lambda x: x > 6.69864257)
listingsNYC
# Out:
# C:\Users\Roger\AppData\Local\Temp\ipykernel_7924\421778703.py:2: FutureWarning: Behavior when concatenating bool-dtype and numeric-dtype arrays is deprecated; in a future version these will cast to object dtype (instead of coercing bools to numeric values). To retain the old behavior, explicitly cast bool-dtype arrays to numeric dtype.
#   listingsNYC.loc['is_budget'] = listingsNYC['log_pps'].apply(lambda x: x < 6.69864257)
# C:\Users\Roger\AppData\Local\Temp\ipykernel_7924\421778703.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   listingsNYC.loc['is_budget'] = listingsNYC['log_pps'].apply(lambda x: x < 6.69864257)
# C:\Users\Roger\AppData\Local\Temp\ipykernel_7924\421778703.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   listingsNYC['is_luxury'] = listingsNYC['log_pps'].apply(lambda x: x > 6.69864257)
#                            id                                          name  \
# 0                        5136      Spacious Brooklyn Duplex, Patio + Garden
# 1                        5203            Cozy Clean Guest Room - Family Apt
# 2                        5121                               BlissArtsSpace!
# 3                        5178              Large Furnished Room Near B'way
# 4                        2595                         Skylit Midtown Castle
# ...                       ...                                           ...
# 41160      769612968972941927                 Comfortable 1 bedroom ROOM #3
# 41175      770593748958588679  Luxury Brooklyn apt. | 10 mins away from JFK
# 41218      769850569510129629                 Private Bed Manhattan 20 Mins
# 41431      773290288588713925              Modern Luxury- Chelsea Townhouse
# is_budget                 NaN                                           NaN
#
#              host_id neighbourhood_group       neighbourhood        room_type  \
# 0               7378            Brooklyn         Sunset Park  Entire home/apt
# 1               7490           Manhattan     Upper West Side     Private room
# 2               7356            Brooklyn  Bedford-Stuyvesant     Private room
# 3               8967           Manhattan             Midtown     Private room
# 4               2845           Manhattan             Midtown  Entire home/apt
# ...              ...                 ...                 ...              ...
# 41160      162927656              Queens             Jamaica      Shared room
# 41175      489532090            Brooklyn       East New York  Entire home/apt
# 41218      324722741              Queens            Woodside     Private room
# 41431      371921352           Manhattan             Chelsea  Entire home/apt
# is_budget        NaN                 NaN                 NaN              NaN
#
#             price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0           275.0            21.0                3.0               0.03
# 1            75.0             2.0              118.0               0.73
# 2            60.0            30.0               50.0               0.30
# 3            68.0             2.0              559.0               3.38
# 4           175.0            30.0               49.0               0.31
# ...           ...             ...                ...                ...
# 41160        91.0             1.0                1.0               1.00
# 41175       145.0             1.0                2.0               2.00
# 41218        50.0             1.0                1.0               1.00
# 41431      2000.0             3.0                1.0               1.00
# is_budget     NaN             NaN                NaN                NaN
#
#            calculated_host_listings_count  availability_365  \
# 0                                     1.0             267.0
# 1                                     1.0               0.0
# 2                                     2.0             322.0
# 3                                     1.0              79.0
# 4                                     3.0             365.0
# ...                                   ...               ...
# 41160                                 7.0             174.0
# 41175                                 1.0             351.0
# 41218                                 1.0             240.0
# 41431                                 1.0             338.0
# is_budget                             NaN               NaN
#
#            number_of_reviews_ltm     pps  log_price   log_pps  is_budget  \
# 0                            1.0  5775.0   5.616771  8.661294        0.0
# 1                            0.0   150.0   4.317488  5.010635        1.0
# 2                            0.0  1800.0   4.094345  7.495542        0.0
# 3                           50.0   136.0   4.219508  4.912655        1.0
# 4                            1.0  5250.0   5.164786  8.565983        0.0
# ...                          ...     ...        ...       ...        ...
# 41160                        1.0    91.0   4.510860  4.510860        1.0
# 41175                        2.0   145.0   4.976734  4.976734        1.0
# 41218                        1.0    50.0   3.912023  3.912023        1.0
# 41431                        1.0  6000.0   7.600902  8.699515        0.0
# is_budget                    NaN     NaN        NaN       NaN        NaN
#
#            is_luxury
# 0               True
# 1              False
# 2               True
# 3              False
# 4               True
# ...              ...
# 41160          False
# 41175          False
# 41218          False
# 41431           True
# is_budget      False
#
# [32119 rows x 18 columns]

# %%
def get_outlier_bounds(col_name):
    '''
    Gets the bound for outliers in the dataset. This is to make the visualizations easier. This function is 
    specifically for this usage and dataset
     
    Param:
        col_name: the name of the column for which you want the bounds. Must be a numerical column
    Return:
        A tuple with the col_name, upper_bound and lower_bound
    '''
    iqr = describe_df.loc['75%',col_name] - describe_df.loc['25%',col_name]
    upper_bound = describe_df.loc['75%',col_name] + (1.5* iqr)
    lower_bound = describe_df.loc['25%',col_name] - (1.5*iqr)
    print(col_name)
    print('upper bound ' + upper_bound.astype(str))
    print('lower bound ' + lower_bound.astype(str))
    print('-'*50)
    return (col_name,upper_bound,lower_bound)

# %%
# filtering out the outliers
# We only want the numeric columns because the get_outlier_bounds won't work on strings
numeric_cols = listingsNYC.select_dtypes(include=np.number)
for column in numeric_cols.columns:
    listingsNYC = listingsNYC[(listingsNYC[column] < get_outlier_bounds(column)[1]) & (listingsNYC[column] > get_outlier_bounds(column)[2])]
listingsNYC
# Out:
#                        id                                               name  \
# 0                    5136           Spacious Brooklyn Duplex, Patio + Garden
# 2                    5121                                    BlissArtsSpace!
# 4                    2595                              Skylit Midtown Castle
# 5                    6872  Uptown Sanctuary w/ Private Bath (Month to Month)
# 11                   7801                   Sweet and Spacious Brooklyn Loft
# ...                   ...                                                ...
# 41036  768899741442488288                           this is studio apartment
# 41056  768239303625460600                         Apartment in Corona Queens
# 41066  769046532467871799                   Entire 3 bedroom apt - Sunnyside
# 41175  770593748958588679       Luxury Brooklyn apt. | 10 mins away from JFK
# 41218  769850569510129629                      Private Bed Manhattan 20 Mins
#
#          host_id neighbourhood_group       neighbourhood        room_type  \
# 0           7378            Brooklyn         Sunset Park  Entire home/apt
# 2           7356            Brooklyn  Bedford-Stuyvesant     Private room
# 4           2845           Manhattan             Midtown  Entire home/apt
# 5          16104           Manhattan         East Harlem     Private room
# 11         21207            Brooklyn        Williamsburg  Entire home/apt
# ...          ...                 ...                 ...              ...
# 41036  488754388              Queens            Glendale  Entire home/apt
# 41056  105692628              Queens     Jackson Heights  Entire home/apt
# 41066  188096291              Queens           Sunnyside  Entire home/apt
# 41175  489532090            Brooklyn       East New York  Entire home/apt
# 41218  324722741              Queens            Woodside     Private room
#
#        price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0        275              21                  3               0.03
# 2         60              30                 50               0.30
# 4        175              30                 49               0.31
# 5         65              30                  1               0.16
# 11       395              30                  9               0.06
# ...      ...             ...                ...                ...
# 41036    106               1                  1               1.00
# 41056    140               1                  1               1.00
# 41066    130               1                  1               1.00
# 41175    145               1                  2               2.00
# 41218     50               1                  1               1.00
#
#        calculated_host_listings_count  availability_365  \
# 0                                   1               267
# 2                                   2               322
# 4                                   3               365
# 5                                   2               300
# 11                                  1               332
# ...                               ...               ...
# 41036                               1               346
# 41056                               1               350
# 41066                               1               355
# 41175                               1               351
# 41218                               1               240
#
#        number_of_reviews_ltm     ppn
# 0                          1   13.10
# 2                          0    2.00
# 4                          1    5.83
# 5                          1    2.17
# 11                         0   13.17
# ...                      ...     ...
# 41036                      1  106.00
# 41056                      1  140.00
# 41066                      1  130.00
# 41175                      2  145.00
# 41218                      1   50.00
#
# [19473 rows x 14 columns]

# %%
sns.displot((luxury['log_pps']), kde=True, color='blue')

# %%
sns.scatterplot(x='minimum_nights',y='log_pps',hue ='neighbourhood_group' , data=luxury)
# Out:
# <AxesSubplot:xlabel='minimum_nights', ylabel='log_pps'>

# %%
# boxplot with the x would be the _____ and the y would be ______
