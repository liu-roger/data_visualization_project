# %% [markdown]
# # Preparing the Dataset

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
plt.style.use('ggplot')
import seaborn as sns
import geopandas as gpd
import geoplot as gplt
from shapely.geometry import Point
import geoplot.crs as gcrs
import contextily as cx
from geopandas.tools import overlay
import mapclassify as mc
import warnings
warnings.filterwarnings('ignore')

# %%
# Kept the original dataset
listingsNYC = pd.read_csv('listings.csv', dtype=object)
# Dropping all of the columns which we will not use
# listingsNYC= listingsNYC.drop(['last_review','license','latitude','longitude','host_name'], axis=1)

# Dropping all rows with any 'Nan' values in them
# listingsNYC.dropna(axis=0, how='any', inplace=True)
data_types_dict = {
    'price':'int64', 
    'minimum_nights':'int64', 
    'host_id':str,
    'number_of_reviews':'int64',
    'reviews_per_month':float,
    'calculated_host_listings_count':'int64',
    'availability_365':'int64',
    'number_of_reviews_ltm':'int64',
    'latitude':float,
    'longitude':float
}

#changing all the datatype to their respective types that we can work with
listingsNYC = listingsNYC.astype(data_types_dict)

# creating a price per stay (ppn) column with the price and minimim nights columns and rounding to 2 decimal places. 
# This is a float dtype 
listingsNYC['pps'] = (listingsNYC['price'] * listingsNYC['minimum_nights']).round(2)
listingsNYC['neighbourhood'].unique().shape[0]
listingsNYC.describe()
listingsNYC['annual_revenue'] = (365 - listingsNYC['availability_365']) *  listingsNYC['price']
listingsNYC = listingsNYC[(listingsNYC['price'] != 0)]
listingsNYC.loc[:,'log_price']=np.log(listingsNYC['price'])
listingsNYC.loc[:,'log_pps']=np.log(listingsNYC['pps'])
# listingsNYC['price_bin'] = pd.cut(listingsNYC['price'], bins=range(0, 111, 10), right=False, labels=range(0, 110, 10))
df = listingsNYC[(listingsNYC['price']<2000) & (listingsNYC['price']>20) & (listingsNYC['minimum_nights'] < 30)]
df['price_bin'] = pd.cut(df['price'], bins=range(0, 2001, 20), right=False, labels=range(0, 2000, 20))
df
# Out:
#                        id                                               name  \
# 0                    5136           Spacious Brooklyn Duplex, Patio + Garden
# 1                    5203                 Cozy Clean Guest Room - Family Apt
# 3                    5178                   Large Furnished Room Near B'way
# 6                    5803  Lovely Room 1 in BEST AREA; Legal Rental, Spot...
# 8                    7097        Perfect for Your Parents:  Privacy + Garden
# ...                   ...                                                ...
# 41525  772714221060214808                            Good Vibes at The Bronx
# 41526  772716724205003579                  2 bedroom Condo near West Village
# 41527  771961589340472067                                 Habitación Privada
# 41528  771962449581256963                                Romántico y natural
# 41532  771975190766692224           Lovely  Big Studio for Rental Bronx City
#
# ...

# %%
brooklyn_home = df[(df['neighbourhood_group']=='Brooklyn') & (df['room_type']=='Entire home/apt')]
brooklyn_private = df[(df['neighbourhood_group']=='Brooklyn') & (df['room_type']=='Private room')]
brooklyn_hotel = df[(df['neighbourhood_group']=='Brooklyn') & (df['room_type']=='Hotel room')]
brooklyn_shared = df[(df['neighbourhood_group']=='Brooklyn') & (df['room_type']=='Shared room')]


manhattan_home = df[(df['neighbourhood_group']=='Manhattan')  & (df['room_type']=='Entire home/apt')]
manhattan_private = df[(df['neighbourhood_group']=='Manhattan') & (df['room_type']=='Private room')]
manhattan_hotel = df[(df['neighbourhood_group']=='Manhattan') & (df['room_type']=='Hotel room')]
manhattan_shared = df[(df['neighbourhood_group']=='Manhattan') & (df['room_type']=='Shared room')]

queens_home = df[(df['neighbourhood_group']=='Queens')  & (df['room_type']=='Entire home/apt')]
queens_private = df[(df['neighbourhood_group']=='Queens') & (df['room_type']=='Private room')]
queens_hotel = df[(df['neighbourhood_group']=='Queens') & (df['room_type']=='Hotel room')]
queens_shared = df[(df['neighbourhood_group']=='Queens') & (df['room_type']=='Shared room')]

bronx_home = df[(df['neighbourhood_group']=='Bronx')  & (df['room_type']=='Entire home/apt')]
bronx_private = df[(df['neighbourhood_group']=='Bronx') & (df['room_type']=='Private room')]
bronx_hotel = df[(df['neighbourhood_group']=='Bronx') & (df['room_type']=='Hotel room')]
bronx_shared = df[(df['neighbourhood_group']=='Bronx') & (df['room_type']=='Shared room')]

staten_island_home = df[(df['neighbourhood_group']=='Staten Island')  & (df['room_type']=='Entire home/apt')]
staten_island_private = df[(df['neighbourhood_group']=='Staten Island') & (df['room_type']=='Private room')]
staten_island_hotel = df[(df['neighbourhood_group']=='Staten Island') & (df['room_type']=='Hotel room')]
staten_island_shared = df[(df['neighbourhood_group']=='Staten Island') & (df['room_type']=='Shared room')]

# %%
sns.set_style({'axes.facecolor': 'white','axes.edgecolor': 'grey','axes.spines.right': False, 'axes.spines.top': False, 'xtick.color': 'grey', 'ytick.color': 'grey'})

# %% [markdown]
# # brooklyn_home

# %%
brooklyn_home_grouping_mean =  brooklyn_home.groupby('price_bin').mean()
brooklyn_home_grouping_count = brooklyn_home.groupby('price_bin').count()
brooklyn_home_grouping_count = brooklyn_home_grouping_count[['price']]
brooklyn_home_grouping_count.rename(columns={'price':'price_bin_count'}, inplace=True)
brooklyn_home_grouping = pd.merge(brooklyn_home_grouping_mean,brooklyn_home_grouping_count, how = 'left', on= 'price_bin')

# %%
# sns.set_style({'axes.facecolor': 'white','axes.edgecolor': 'grey','axes.spines.right': False, 'axes.spines.top': False})
fig, axes = plt.subplots(2, 2)
sns.lineplot(x = brooklyn_home_grouping.index, y = 'price_bin_count', data=brooklyn_home_grouping,ax=axes[0,0],color='#A6DAF7')
sns.lineplot(x = brooklyn_home_grouping.index, y = 'availability_365', data=brooklyn_home_grouping,ax=axes[0,1],color='#A6DAF7')
sns.lineplot(x = brooklyn_home_grouping.index, y = 'annual_revenue', data=brooklyn_home_grouping,ax=axes[1,0],color='#A6DAF7')
# Out:
# <Axes: xlabel='price_bin', ylabel='annual_revenue'>

# %%
sns.lineplot(x = brooklyn_home_grouping.index, y = 'price_bin_count', data=brooklyn_home_grouping,color='#A6DAF7')
plt.title('Number of Listings for Each Price Bin in Brooklyn Home Type')
plt.xlabel('Price Bin')
plt.ylabel('Number of Listings')
# Out:
# Text(0, 0.5, 'Number of Listings')

# %%
sns.lineplot(x = brooklyn_home_grouping.index, y = 'availability_365', data=brooklyn_home_grouping,color='#A6DAF7')
plt.title('Average Days a Listing is not Booked in Brooklyn Home Type')
plt.xlabel('Price Bin')
plt.ylabel('Average Days Listing is not Booked')
# Out:
# Text(0, 0.5, 'Average Days Listing is not Booked')

# %%
sns.lineplot(x = brooklyn_home_grouping.index, y = 'annual_revenue', data=brooklyn_home_grouping,color='#A6DAF7')
plt.title('Estimated Annual Revenue for Brooklyn Home Type')
plt.xlabel('Price Bin')
plt.ylabel('Estimated Annual Revenue')
# Out:
# Text(0, 0.5, 'Estimated Annual Revenue')

# %% [markdown]
# # brooklyn_private

# %%
brooklyn_private_grouping_mean =  brooklyn_private.groupby('price_bin').mean()
brooklyn_private_grouping_count = brooklyn_private.groupby('price_bin').count()
brooklyn_private_grouping_count = brooklyn_private_grouping_count[['price']]
brooklyn_private_grouping_count.rename(columns={'price':'price_bin_count'}, inplace=True)
brooklyn_private_grouping = pd.merge(brooklyn_private_grouping_mean,brooklyn_private_grouping_count, how = 'left', on= 'price_bin')

# %%
fig, axes = plt.subplots(2, 2)
sns.lineplot(x = brooklyn_private_grouping.index, y = 'price_bin_count', data=brooklyn_private_grouping,ax=axes[0,0],color='#A6DAF7')
sns.lineplot(x = brooklyn_private_grouping.index, y = 'availability_365', data=brooklyn_private_grouping,ax=axes[0,1],color='#A6DAF7')
sns.lineplot(x = brooklyn_private_grouping.index, y = 'annual_revenue', data=brooklyn_private_grouping,ax=axes[1,0],color='#A6DAF7')
# Out:
# <Axes: xlabel='price_bin', ylabel='annual_revenue'>

# %%
sns.lineplot(x = brooklyn_private_grouping.index, y = 'price_bin_count', data=brooklyn_private_grouping,color='#A6DAF7')
plt.title('Number of Listings for Each Price Bin in Brooklyn Private Type')
plt.xlabel('Price Bin')
plt.ylabel('Number of Listings')
# Out:
# Text(0, 0.5, 'Number of Listings')

# %%
sns.lineplot(x = brooklyn_private_grouping.index, y = 'availability_365', data=brooklyn_private_grouping,color='#A6DAF7')
plt.title('Average Days a Listing is not Booked in Brooklyn Private Type')
plt.xlabel('Price Bin')
plt.ylabel('Average Days Listing is not Booked')
# Out:
# Text(0, 0.5, 'Average Days Listing is not Booked')

# %%
sns.lineplot(x = brooklyn_private_grouping.index, y = 'annual_revenue', data=brooklyn_private_grouping,color='#A6DAF7')
plt.title('Estimated Annual Revenue for Brooklyn Private Type')
plt.xlabel('Price Bin')
plt.ylabel('Estimated Annual Revenue')
# Out:
# Text(0, 0.5, 'Estimated Annual Revenue')

# %% [markdown]
# # brooklyn_hotel

# %%
brooklyn_hotel_grouping_mean =  brooklyn_hotel.groupby('price_bin').mean()
brooklyn_hotel_grouping_count = brooklyn_hotel.groupby('price_bin').count()
brooklyn_hotel_grouping_count = brooklyn_hotel_grouping_count[['price']]
brooklyn_hotel_grouping_count.rename(columns={'price':'price_bin_count'}, inplace=True)
brooklyn_hotel_grouping = pd.merge(brooklyn_hotel_grouping_mean,brooklyn_hotel_grouping_count, how = 'left', on= 'price_bin')

# %%
fig, axes = plt.subplots(2, 2)
sns.lineplot(x = brooklyn_hotel_grouping.index, y = 'price_bin_count', data=brooklyn_hotel_grouping,ax=axes[0,0],color='#A6DAF7')
sns.lineplot(x = brooklyn_hotel_grouping.index, y = 'availability_365', data=brooklyn_hotel_grouping,ax=axes[0,1],color='#A6DAF7')
sns.lineplot(x = brooklyn_hotel_grouping.index, y = 'annual_revenue', data=brooklyn_hotel_grouping,ax=axes[1,0],color='#A6DAF7')
# Out:
# <Axes: xlabel='price_bin', ylabel='annual_revenue'>

# %% [markdown]
# # brooklyn_shared

# %%
brooklyn_shared_grouping_mean =  brooklyn_shared.groupby('price_bin').mean()
brooklyn_shared_grouping_count = brooklyn_shared.groupby('price_bin').count()
brooklyn_shared_grouping_count = brooklyn_shared_grouping_count[['price']]
brooklyn_shared_grouping_count.rename(columns={'price':'price_bin_count'}, inplace=True)
brooklyn_shared_grouping = pd.merge(brooklyn_hotel_grouping_mean,brooklyn_hotel_grouping_count, how = 'left', on= 'price_bin')

# %%
fig, axes = plt.subplots(2, 2)
sns.lineplot(x = brooklyn_shared_grouping.index, y = 'price_bin_count', data=brooklyn_shared_grouping,ax=axes[0,0],color='#A6DAF7')
sns.lineplot(x = brooklyn_shared_grouping.index, y = 'availability_365', data=brooklyn_shared_grouping,ax=axes[0,1],color='#A6DAF7')
sns.lineplot(x = brooklyn_shared_grouping.index, y = 'annual_revenue', data=brooklyn_shared_grouping,ax=axes[1,0],color='#A6DAF7')
# Out:
# <Axes: xlabel='price_bin', ylabel='annual_revenue'>

# %% [markdown]
# # manhattan_home

# %%
manhattan_home_grouping_mean =  manhattan_home.groupby('price_bin').mean()
manhattan_home_grouping_count = manhattan_home.groupby('price_bin').count()
manhattan_home_grouping_count = manhattan_home_grouping_count[['price']]
manhattan_home_grouping_count.rename(columns={'price':'price_bin_count'}, inplace=True)
manhattan_home_grouping = pd.merge(manhattan_home_grouping_mean,manhattan_home_grouping_count, how = 'left', on= 'price_bin')

# %%
fig, axes = plt.subplots(2, 2)
sns.lineplot(x = manhattan_home_grouping.index, y = 'price_bin_count', data=manhattan_home_grouping,ax=axes[0,0],color='#A6DAF7')
sns.lineplot(x = manhattan_home_grouping.index, y = 'availability_365', data=manhattan_home_grouping,ax=axes[0,1],color='#A6DAF7')
sns.lineplot(x = manhattan_home_grouping.index, y = 'annual_revenue', data=manhattan_home_grouping,ax=axes[1,0],color='#A6DAF7')
# Out:
# <Axes: xlabel='price_bin', ylabel='annual_revenue'>

# %%
sns.lineplot(x = manhattan_home_grouping.index, y = 'price_bin_count', data=manhattan_home_grouping,color='#A6DAF7')
plt.title('Number of Listings for Each Price Bin in Manhattan Home Type')
plt.xlabel('Price Bin')
plt.ylabel('Estimated Annual Revenue')
# Out:
# Text(0, 0.5, 'Estimated Annual Revenue')

# %%
sns.lineplot(x = manhattan_home_grouping.index, y = 'availability_365', data=manhattan_home_grouping,color='#A6DAF7')
plt.title('Average Days a Listing is not Booked in Manhattan Home Type')
plt.xlabel('Price Bin')
plt.ylabel('Average Days Listing is not Booked')
# Out:
# Text(0, 0.5, 'Average Days Listing is not Booked')

# %%
sns.lineplot(x = manhattan_home_grouping.index, y = 'annual_revenue', data=manhattan_home_grouping,color='#A6DAF7')
plt.title('Estimated Annual Revenue for Manhattan Home Type')
plt.xlabel('Price Bin')
plt.ylabel('Estimated Annual Revenue')
# Out:
# Text(0, 0.5, 'Estimated Annual Revenue')

# %% [markdown]
# # manhattan_private

# %%
manhattan_private_grouping_mean =  manhattan_private.groupby('price_bin').mean()
manhattan_private_grouping_count = manhattan_private.groupby('price_bin').count()
manhattan_private_grouping_count = manhattan_private_grouping_count[['price']]
manhattan_private_grouping_count.rename(columns={'price':'price_bin_count'}, inplace=True)
manhattan_private_grouping = pd.merge(manhattan_private_grouping_mean,manhattan_private_grouping_count, how = 'left', on= 'price_bin')

# %%
fig, axes = plt.subplots(2, 2)
sns.lineplot(x = manhattan_private_grouping.index, y = 'price_bin_count', data=manhattan_private_grouping,ax=axes[0,0],color='#A6DAF7')
sns.lineplot(x = manhattan_private_grouping.index, y = 'availability_365', data=manhattan_private_grouping,ax=axes[0,1],color='#A6DAF7')
sns.lineplot(x = manhattan_private_grouping.index, y = 'annual_revenue', data=manhattan_private_grouping,ax=axes[1,0],color='#A6DAF7')
# Out:
# <Axes: xlabel='price_bin', ylabel='annual_revenue'>

# %%
sns.lineplot(x = manhattan_private_grouping.index, y = 'price_bin_count', data=manhattan_private_grouping,color='#A6DAF7')
plt.title('Number of Listings for Each Price Bin in Manhattan Private Type')
plt.xlabel('Price Bin')
plt.ylabel('Numbers of Listings')
# Out:
# Text(0, 0.5, 'Numbers of Listings')

# %%
sns.lineplot(x = manhattan_private_grouping.index, y = 'availability_365', data=manhattan_private_grouping,color='#A6DAF7')
plt.title('Average Days a Listing is not Booked in Manhattan Private Type')
plt.xlabel('Price Bin')
plt.ylabel('Average Days Listing is not Booked')
# Out:
# Text(0, 0.5, 'Average Days Listing is not Booked')

# %%
sns.lineplot(x = manhattan_private_grouping.index, y = 'annual_revenue', data=manhattan_private_grouping,color='#A6DAF7')
plt.title('Estimated Annual Revenue for Manhattan Private Type')
plt.xlabel('Price Bin')
plt.ylabel('Estimated Annual Revenue')
# Out:
# Text(0, 0.5, 'Estimated Annual Revenue')

# %%
temp = manhattan_private_grouping.copy(deep=True)
temp.reset_index(inplace=True)
temp['price_bin'].astype(int)
temp[(temp['price_bin']>220) & (temp['price_bin']<340)]
# Out:
#    price_bin   latitude  longitude       price  minimum_nights  \
# 12       240  40.770959 -73.972307  250.490909        2.672727
# 13       260  40.753756 -73.983187  269.886364        1.909091
# 14       280  40.756239 -73.982355  291.307692        1.653846
# 15       300  40.759884 -73.982741  309.411765        1.367647
# 16       320  40.757850 -73.982018  327.550000        1.325000
#
#     number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 12          21.054545           1.348095                        6.254545
# 13          56.931818           3.059655                       10.477273
# 14          38.961538           1.656818                       17.923077
# 15           9.514706           0.595455                       35.750000
# 16          18.975000           0.913529                       37.150000
#
#     availability_365  number_of_reviews_ltm         pps  annual_revenue  \
# ...

# %%
manhattan_private_grouping[(manhattan_private_grouping['price']<400) & (manhattan_private_grouping['price']>300) ].count()
# Out:
# latitude                          5
# longitude                         5
# price                             5
# minimum_nights                    5
# number_of_reviews                 5
# reviews_per_month                 5
# calculated_host_listings_count    5
# availability_365                  5
# number_of_reviews_ltm             5
# pps                               5
# annual_revenue                    5
# log_price                         5
# log_pps                           5
# price_bin_count                   5
# dtype: int64

# %% [markdown]
# There is a potential spot in the market at $300. Spot at 260 and 280 may want to have a price bump. This may be due to user filtering for listings above 300. Looking at the filtering or beause of the listing location.

# %% [markdown]
# # manhattan_hotel

# %%
manhattan_hotel_grouping_mean =  manhattan_hotel.groupby('price_bin').mean()
manhattan_hotel_grouping_count = manhattan_hotel.groupby('price_bin').count()
manhattan_hotel_grouping_count = manhattan_hotel_grouping_count[['price']]
manhattan_hotel_grouping_count.rename(columns={'price':'price_bin_count'}, inplace=True)
manhattan_hotel_grouping = pd.merge(manhattan_hotel_grouping_mean,manhattan_hotel_grouping_count, how = 'left', on= 'price_bin')

# %%
fig, axes = plt.subplots(2, 2)
sns.lineplot(x = manhattan_hotel_grouping.index, y = 'price_bin_count', data=manhattan_hotel_grouping,ax=axes[0,0],color='#A6DAF7')
sns.lineplot(x = manhattan_hotel_grouping.index, y = 'availability_365', data=manhattan_hotel_grouping,ax=axes[0,1],color='#A6DAF7')
sns.lineplot(x = manhattan_hotel_grouping.index, y = 'annual_revenue', data=manhattan_hotel_grouping,ax=axes[1,0],color='#A6DAF7')
# Out:
# <Axes: xlabel='price_bin', ylabel='annual_revenue'>

# %% [markdown]
# # manhattan_shared

# %%
manhattan_shared_grouping_mean =  manhattan_shared.groupby('price_bin').mean()
manhattan_shared_grouping_count = manhattan_shared.groupby('price_bin').count()
manhattan_shared_grouping_count = manhattan_shared_grouping_count[['price']]
manhattan_shared_grouping_count.rename(columns={'price':'price_bin_count'}, inplace=True)
manhattan_shared_grouping = pd.merge(manhattan_shared_grouping_mean,manhattan_shared_grouping_count, how = 'left', on= 'price_bin')

# %%
fig, axes = plt.subplots(2, 2)
sns.lineplot(x = manhattan_shared_grouping.index, y = 'price_bin_count', data=manhattan_shared_grouping,ax=axes[0,0],color='#A6DAF7')
sns.lineplot(x = manhattan_shared_grouping.index, y = 'availability_365', data=manhattan_shared_grouping,ax=axes[0,1],color='#A6DAF7')
sns.lineplot(x = manhattan_shared_grouping.index, y = 'annual_revenue', data=manhattan_shared_grouping,ax=axes[1,0],color='#A6DAF7')
# Out:
# <Axes: xlabel='price_bin', ylabel='annual_revenue'>

# %%
sns.lineplot(x = manhattan_private_grouping.index, y = 'availability_365', data=manhattan_private_grouping)
# Out:
# <Axes: xlabel='price_bin', ylabel='availability_365'>

# %%
sns.lineplot(x = manhattan_private_grouping.index, y = 'annual_revenue', data=manhattan_private_grouping)
# Out:
# <Axes: xlabel='price_bin', ylabel='annual_revenue'>

# %% [markdown]
# # Bronx Home

# %%
bronx_home_grouping_mean =  bronx_home.groupby('price_bin').mean()
bronx_home_grouping_count = bronx_home.groupby('price_bin').count()
bronx_home_grouping_count = bronx_home_grouping_count[['price']]
bronx_home_grouping_count.rename(columns={'price':'price_bin_count'}, inplace=True)
bronx_home_grouping = pd.merge(bronx_home_grouping_mean,bronx_home_grouping_count, how = 'left', on= 'price_bin')

# %%
fig, axes = plt.subplots(2, 2)
sns.lineplot(x = bronx_home_grouping.index, y = 'price_bin_count', data=bronx_home_grouping,ax=axes[0,0],color='#A6DAF7')
sns.lineplot(x = bronx_home_grouping.index, y = 'availability_365', data=bronx_home_grouping,ax=axes[0,1],color='#A6DAF7')
sns.lineplot(x = bronx_home_grouping.index, y = 'annual_revenue', data=bronx_home_grouping,ax=axes[1,0],color='#A6DAF7')
# Out:
# <Axes: xlabel='price_bin', ylabel='annual_revenue'>

# %%
sns.lineplot(x = bronx_home_grouping.index, y = 'price_bin_count', data=bronx_home_grouping,color='#A6DAF7')
plt.title('Number of Listings for Each Price Bin in Bronx Home Type')
plt.xlabel('Price Bin')
plt.ylabel('Numbers of Listings')
# Out:
# Text(0, 0.5, 'Numbers of Listings')

# %%
sns.lineplot(x = bronx_home_grouping.index, y = 'availability_365', data=bronx_home_grouping,color='#A6DAF7')
plt.title('Average Days a Listing is not Booked in Bronx Home Type')
plt.xlabel('Price Bin')
plt.ylabel('Average Days Listing is not Booked')
# Out:
# Text(0, 0.5, 'Average Days Listing is not Booked')

# %%
sns.lineplot(x = bronx_home_grouping.index, y = 'annual_revenue', data=bronx_home_grouping,color='#A6DAF7')
plt.title('Number of Listings for Each Price Bin in Bronx Home Type')
plt.xlabel('Price Bin')
plt.ylabel('Estimated Annual Revenue')
# Out:
# Text(0, 0.5, 'Estimated Annual Revenue')

# %% [markdown]
# # Bronx Private

# %%
bronx_private_grouping_mean =  bronx_private.groupby('price_bin').mean()
bronx_private_grouping_count = bronx_private.groupby('price_bin').count()
bronx_private_grouping_count = bronx_private_grouping_count[['price']]
bronx_private_grouping_count.rename(columns={'price':'price_bin_count'}, inplace=True)
bronx_private_grouping = pd.merge(bronx_private_grouping_mean,bronx_private_grouping_count, how = 'left', on= 'price_bin')

# %%
fig, axes = plt.subplots(2, 2)
sns.lineplot(x = bronx_private_grouping.index, y = 'price_bin_count', data=bronx_private_grouping,ax=axes[0,0],color='#A6DAF7')
sns.lineplot(x = bronx_private_grouping.index, y = 'availability_365', data=bronx_private_grouping,ax=axes[0,1],color='#A6DAF7')
sns.lineplot(x = bronx_private_grouping.index, y = 'annual_revenue', data=bronx_private_grouping,ax=axes[1,0],color='#A6DAF7')
# Out:
# <Axes: xlabel='price_bin', ylabel='annual_revenue'>

# %%
sns.lineplot(x = bronx_private_grouping.index, y = 'price_bin_count', data=bronx_private_grouping,color='#A6DAF7')
plt.title('Number of Listings for Each Price Bin in Bronx Private Type')
plt.xlabel('Price Bin')
plt.ylabel('Numbers of Listings')
# Out:
# Text(0, 0.5, 'Numbers of Listings')

# %%
sns.lineplot(x = bronx_private_grouping.index, y = 'availability_365', data=bronx_private_grouping,color='#A6DAF7')
plt.title('Average Days a Listing is not Booked in Bronx Private Type')
plt.xlabel('Price Bin')
plt.ylabel('Average Days Listing is not Booked')
# Out:
# Text(0, 0.5, 'Average Days Listing is not Booked')

# %%
sns.lineplot(x = bronx_private_grouping.index, y = 'annual_revenue', data=bronx_private_grouping,color='#A6DAF7')
plt.title('Number of Listings for Each Price Bin in Bronx Private Type')
plt.xlabel('Price Bin')
plt.ylabel('Estimated Annual Revenue')
# Out:
# Text(0, 0.5, 'Estimated Annual Revenue')
