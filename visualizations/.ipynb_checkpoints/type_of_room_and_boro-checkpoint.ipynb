# %% [markdown]
# # Preparing the Dataset

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
plt.style.use('ggplot')
import seaborn as sns
# import warnings
# warnings.filterwarnings('ignore')

# %%
# Kept the original dataset
listingsNYC = pd.read_csv('listings.csv', dtype=object)

# %%
# Dropping all of the columns which we will not use
# listingsNYC= listingsNYC.drop(['last_review','license','latitude','longitude','host_name'], axis=1)

# Dropping all rows with any 'Nan' values in them
# listingsNYC.dropna(axis=0, how='any', inplace=True)
data_types_dict = {
    'price':'int64', 
    'minimum_nights':'int64', 
    'host_id':str,
    'number_of_reviews':'int64',
    'reviews_per_month':float,
    'calculated_host_listings_count':'int64',
    'availability_365':'int64',
    'number_of_reviews_ltm':'int64'}

#changing all the datatype to their respective types that we can work with
listingsNYC = listingsNYC.astype(data_types_dict)

# creating a price per stay (ppn) column with the price and minimim nights columns and rounding to 2 decimal places. 
# This is a float dtype 
listingsNYC['pps'] = (listingsNYC['price'] * listingsNYC['minimum_nights']).round(2)
listingsNYC['neighbourhood'].unique().shape[0]
listingsNYC.describe()
listingsNYC['annual_revenue'] = (365 - listingsNYC['availability_365']) *  listingsNYC['price']
listingsNYC = listingsNYC[(listingsNYC['price'] != 0)]
listingsNYC.loc[:,'log_price']=np.log(listingsNYC['price'])
listingsNYC.loc[:,'log_pps']=np.log(listingsNYC['pps'])
listingsNYC.loc[:,'is_budget'] = listingsNYC['log_pps'].apply(lambda x: x < 6.69864257)
listingsNYC.loc[:,'is_luxury'] = listingsNYC['log_pps'].apply(lambda x: x > 6.69864257)
listingsNYC
# listingsNYC['price_bin'] = pd.cut(listingsNYC['price'], bins=range(0, 111, 10), right=False, labels=range(0, 110, 10))
# Out:
#                        id                                               name  \
# 0                    5136           Spacious Brooklyn Duplex, Patio + Garden
# 1                    5203                 Cozy Clean Guest Room - Family Apt
# 2                    5121                                    BlissArtsSpace!
# 3                    5178                   Large Furnished Room Near B'way
# 4                    2595                              Skylit Midtown Castle
# ...                   ...                                                ...
# 41528  771962449581256963                                Romántico y natural
# 41529  771967712456918474                          Sunset Park Studio Sublet
# 41530  771971759808918693     9B5B Townhouse w/ Elevator &  Private Entrance
# 41531  771971822371481471  Huge 9B5B Townhouse w Elevator &  Private Entr...
# 41532  771975190766692224           Lovely  Big Studio for Rental Bronx City
#
#          host_id      host_name neighbourhood_group       neighbourhood  \
# 0           7378        Rebecca            Brooklyn         Sunset Park
# 1           7490      MaryEllen           Manhattan     Upper West Side
# 2           7356          Garon            Brooklyn  Bedford-Stuyvesant
# 3           8967       Shunichi           Manhattan             Midtown
# 4           2845       Jennifer           Manhattan             Midtown
# ...          ...            ...                 ...                 ...
# 41528  421601513    Juan Carlos           Manhattan  Washington Heights
# 41529     326495  Laura Adriana            Brooklyn         Sunset Park
# 41530  316920152        Allison           Manhattan         Murray Hill
# 41531  484979380        Natasha           Manhattan         Murray Hill
# 41532  426540801           Abul               Bronx           Unionport
#
#                 latitude           longitude        room_type  price  ...  \
# 0               40.66265           -73.99454  Entire home/apt    275  ...
# 1                40.8038           -73.96751     Private room     75  ...
# 2               40.68535           -73.95512     Private room     60  ...
# 3               40.76457           -73.98317     Private room     68  ...
# 4               40.75356           -73.98559  Entire home/apt    175  ...
# ...                  ...                 ...              ...    ...  ...
# 41528  40.84727072881559  -73.94341916084775     Private room     80  ...
# 41529  40.63832893587064  -74.01671019409663  Entire home/apt     42  ...
# 41530  40.74690169639175  -73.97826030246593  Entire home/apt   3888  ...
# 41531  40.74959584319043  -73.98079769535242  Entire home/apt   3888  ...
# 41532  40.83282398123486  -73.85237137116201  Entire home/apt     80  ...
#
#        calculated_host_listings_count  availability_365 number_of_reviews_ltm  \
# 0                                   1               267                     1
# 1                                   1                 0                     0
# 2                                   2               322                     0
# 3                                   1                79                    50
# 4                                   3               365                     1
# ...                               ...               ...                   ...
# 41528                               3               358                     0
# 41529                               3                89                     0
# 41530                               8               365                     0
# 41531                               2               364                     0
# 41532                               2               365                     0
#
#        license   pps  annual_revenue  log_price   log_pps  is_budget  \
# 0          NaN  5775           26950   5.616771  8.661294      False
# 1          NaN   150           27375   4.317488  5.010635       True
# 2          NaN  1800            2580   4.094345  7.495542      False
# 3          NaN   136           19448   4.219508  4.912655       True
# 4          NaN  5250               0   5.164786  8.565983      False
# ...        ...   ...             ...        ...       ...        ...
# 41528      NaN   400             560   4.382027  5.991465       True
# 41529      NaN  1260           11592   3.737670  7.138867      False
# 41530      NaN  7776               0   8.265650  8.958797      False
# 41531      NaN  7776            3888   8.265650  8.958797      False
# 41532      NaN   240               0   4.382027  5.480639       True
#
#        is_luxury
# 0           True
# 1          False
# 2           True
# 3          False
# 4           True
# ...          ...
# 41528      False
# 41529       True
# 41530       True
# 41531       True
# 41532      False
#
# [41503 rows x 24 columns]

# %%
df = listingsNYC[(listingsNYC['price']<2000) & (listingsNYC['price']>20) & (listingsNYC['minimum_nights'] < 30)]
df.describe()
# Out:
#               price  minimum_nights  number_of_reviews  reviews_per_month  \
# count  21690.000000    21690.000000       21690.000000       18659.000000
# mean     221.639696        3.418442          38.833287           1.959596
# std      229.568948        4.171019          69.240917           2.265433
# min       22.000000        1.000000           0.000000           0.010000
# 25%       92.000000        1.000000           2.000000           0.560000
# 50%      150.000000        2.000000          13.000000           1.450000
# 75%      255.000000        4.000000          44.000000           2.820000
# max     1999.000000       29.000000        1666.000000         102.980000
#
#        calculated_host_listings_count  availability_365  \
# count                    21690.000000      21690.000000
# mean                         8.148041        171.741263
# std                         25.637217        138.881675
# min                          1.000000          0.000000
# 25%                          1.000000         32.000000
# 50%                          2.000000        156.000000
# 75%                          4.000000        333.000000
# max                        200.000000        365.000000
#
#        number_of_reviews_ltm           pps  annual_revenue     log_price  \
# count           21690.000000  21690.000000    21690.000000  21690.000000
# mean               14.499216    703.313324    40219.488751      5.079702
# std                23.650862   1200.655745    55265.613054      0.755109
# min                 0.000000     28.000000        0.000000      3.091042
# 25%                 1.000000    175.000000     5867.500000      4.521789
# 50%                 7.000000    368.000000    25011.000000      5.010635
# 75%                22.000000    750.000000    52045.500000      5.541264
# max               992.000000  31668.000000   729635.000000      7.600402
#
#             log_pps
# count  21690.000000
# mean       5.933164
# std        1.068130
# min        3.332205
# 25%        5.164786
# 50%        5.908083
# 75%        6.620073
# max       10.363062

# %%
df['price_bin'] = pd.cut(df['price'], bins=range(0, 2001, 20), right=False, labels=range(0, 2000, 20))
df
# Out:
# C:\Users\Roger\AppData\Local\Temp\ipykernel_2376\3098205244.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_bin'] = pd.cut(df['price'], bins=range(0, 2001, 20), right=False, labels=range(0, 2000, 20))
#                        id                                               name  \
# 0                    5136           Spacious Brooklyn Duplex, Patio + Garden
# 1                    5203                 Cozy Clean Guest Room - Family Apt
# 3                    5178                   Large Furnished Room Near B'way
# 6                    5803  Lovely Room 1 in BEST AREA; Legal Rental, Spot...
# 8                    7097        Perfect for Your Parents:  Privacy + Garden
# ...                   ...                                                ...
# 41525  772714221060214808                            Good Vibes at The Bronx
# 41526  772716724205003579                  2 bedroom Condo near West Village
# 41527  771961589340472067                                 Habitación Privada
# 41528  771962449581256963                                Romántico y natural
# 41532  771975190766692224           Lovely  Big Studio for Rental Bronx City
#
#          host_id    host_name neighbourhood_group       neighbourhood  \
# 0           7378      Rebecca            Brooklyn         Sunset Park
# 1           7490    MaryEllen           Manhattan     Upper West Side
# 3           8967     Shunichi           Manhattan             Midtown
# 6           9744       Laurie            Brooklyn         South Slope
# 8          17571         Jane            Brooklyn         Fort Greene
# ...          ...          ...                 ...                 ...
# 41525  421264574       Aridio               Bronx           Unionport
# 41526  481177884       Steven           Manhattan             Chelsea
# 41527  409771624       Camila              Queens           Sunnyside
# 41528  421601513  Juan Carlos           Manhattan  Washington Heights
# 41532  426540801         Abul               Bronx           Unionport
#
#                  latitude           longitude        room_type  price  ...  \
# 0                40.66265           -73.99454  Entire home/apt    275  ...
# 1                 40.8038           -73.96751     Private room     75  ...
# 3                40.76457           -73.98317     Private room     68  ...
# 6                40.66801           -73.98784     Private room    124  ...
# 8               40.691233          -73.972702  Entire home/apt    220  ...
# ...                   ...                 ...              ...    ...  ...
# 41525           40.828074          -73.847886  Entire home/apt    125  ...
# 41526  40.740030367077864  -73.99730227211336  Entire home/apt   1114  ...
# 41527           40.742223           -73.92331     Private room    124  ...
# 41528   40.84727072881559  -73.94341916084775     Private room     80  ...
# 41532   40.83282398123486  -73.85237137116201  Entire home/apt     80  ...
#
#        availability_365  number_of_reviews_ltm license   pps  annual_revenue  \
# 0                   267                      1     NaN  5775           26950
# 1                     0                      0     NaN   150           27375
# 3                    79                     50     NaN   136           19448
# 6                   163                     14     NaN   496           25048
# 8                    38                     36     NaN   660           71940
# ...                 ...                    ...     ...   ...             ...
# 41525                60                      0     NaN   250           38125
# 41526               355                      0     NaN  3342           11140
# 41527               360                      0     NaN   248             620
# 41528               358                      0     NaN   400             560
# 41532               365                      0     NaN   240               0
#
#        log_price   log_pps is_budget  is_luxury  price_bin
# 0       5.616771  8.661294     False       True        260
# 1       4.317488  5.010635      True      False         60
# 3       4.219508  4.912655      True      False         60
# 6       4.820282  6.206576      True      False        120
# 8       5.393628  6.492240      True      False        220
# ...          ...       ...       ...        ...        ...
# 41525   4.828314  5.521461      True      False        120
# 41526   7.015712  8.114325     False       True       1100
# 41527   4.820282  5.513429      True      False        120
# 41528   4.382027  5.991465      True      False         80
# 41532   4.382027  5.480639      True      False         80
#
# [21690 rows x 25 columns]

# %% [markdown]
# This may show that there may be a market at the 225-250 price bin. This is because there seems to be less availbility in the 250 bin. How much would be needed to justify the increase in price into a new price bin? What can you do as a lister to justify the jump in annual revenue?
#
# For example what could I do with 2000 that would justify my client paying $20 more per night.
#
#
#
# There is less competition at 250 than at 200 price bin, while also having what seems to be a higher estimated revenue and lower average availablity meaning there is still demand for this price bin. The amount of listing in this criteria may be underserving the demand.

# %%
brooklyn_home = df[(df['neighbourhood_group']=='Brooklyn') & (df['room_type']=='Entire home/apt')]
brooklyn_private = df[(df['neighbourhood_group']=='Brooklyn') & (df['room_type']=='Private room')]
brooklyn_hotel = df[(df['neighbourhood_group']=='Brooklyn') & (df['room_type']=='Hotel room')]
brooklyn_shared = df[(df['neighbourhood_group']=='Brooklyn') & (df['room_type']=='Shared room')]


manhattan_home = df[(df['neighbourhood_group']=='Manhattan')  & (df['room_type']=='Entire home/apt')]
manhattan_private = df[(df['neighbourhood_group']=='Manhattan') & (df['room_type']=='Private room')]
manhattan_hotel = df[(df['neighbourhood_group']=='Manhattan') & (df['room_type']=='Hotel room')]
manhattan_shared = df[(df['neighbourhood_group']=='Manhattan') & (df['room_type']=='Shared room')]

queens_home = df[(df['neighbourhood_group']=='Queens')  & (df['room_type']=='Entire home/apt')]
queens_private = df[(df['neighbourhood_group']=='Queens') & (df['room_type']=='Private room')]
queens_hotel = df[(df['neighbourhood_group']=='Queens') & (df['room_type']=='Hotel room')]
queens_shared = df[(df['neighbourhood_group']=='Queens') & (df['room_type']=='Shared room')]

bronx_home = df[(df['neighbourhood_group']=='Bronx')  & (df['room_type']=='Entire home/apt')]
bronx_private = df[(df['neighbourhood_group']=='Bronx') & (df['room_type']=='Private room')]
bronx_hotel = df[(df['neighbourhood_group']=='Bronx') & (df['room_type']=='Hotel room')]
bronx_shared = df[(df['neighbourhood_group']=='Bronx') & (df['room_type']=='Shared room')]

staten_island_home = df[(df['neighbourhood_group']=='Staten Island')  & (df['room_type']=='Entire home/apt')]
staten_island_private = df[(df['neighbourhood_group']=='Staten Island') & (df['room_type']=='Private room')]
staten_island_hotel = df[(df['neighbourhood_group']=='Staten Island') & (df['room_type']=='Hotel room')]
staten_island_shared = df[(df['neighbourhood_group']=='Staten Island') & (df['room_type']=='Shared room')]

# %%
brooklyn_home_grouping_mean =  brooklyn_home.groupby('price_bin').mean()
brooklyn_home_grouping_count = brooklyn_home.groupby('price_bin').count()
brooklyn_home_grouping_count = brooklyn_home_grouping_count[['price']]
brooklyn_home_grouping_count.rename(columns={'price':'price_bin_count'}, inplace=True)
brooklyn_home_grouping = pd.merge(brooklyn_home_grouping_mean,brooklyn_home_grouping_count, how = 'left', on= 'price_bin')

# %%
sns.set()
fig, axes = plt.subplots(2, 2)
sns.lineplot(x = brooklyn_home_grouping.index, y = 'price_bin_count', data=brooklyn_home_grouping,ax=axes[0,0])
sns.lineplot(x = brooklyn_home_grouping.index, y = 'availability_365', data=brooklyn_home_grouping,ax=axes[0,1])
sns.lineplot(x = brooklyn_home_grouping.index, y = 'annual_revenue', data=brooklyn_home_grouping,ax=axes[1,0])
# Out:
# <AxesSubplot:xlabel='price_bin', ylabel='annual_revenue'>

# %%
brooklyn_private_grouping_mean =  brooklyn_private.groupby('price_bin').mean()
brooklyn_private_grouping_count = brooklyn_private.groupby('price_bin').count()
brooklyn_private_grouping_count = brooklyn_private_grouping_count[['price']]
brooklyn_private_grouping_count.rename(columns={'price':'price_bin_count'}, inplace=True)
brooklyn_private_grouping = pd.merge(brooklyn_private_grouping_mean,brooklyn_private_grouping_count, how = 'left', on= 'price_bin')

# %%
sns.set()
fig, axes = plt.subplots(2, 2)
sns.lineplot(x = brooklyn_private_grouping.index, y = 'price_bin_count', data=brooklyn_private_grouping,ax=axes[0,0])
sns.lineplot(x = brooklyn_private_grouping.index, y = 'availability_365', data=brooklyn_private_grouping,ax=axes[0,1])
sns.lineplot(x = brooklyn_private_grouping.index, y = 'annual_revenue', data=brooklyn_private_grouping,ax=axes[1,0])
# Out:
# <AxesSubplot:xlabel='price_bin', ylabel='annual_revenue'>

# %%
brooklyn_hotel_grouping_mean =  brooklyn_hotel.groupby('price_bin').mean()
brooklyn_hotel_grouping_count = brooklyn_hotel.groupby('price_bin').count()
brooklyn_hotel_grouping_count = brooklyn_hotel_grouping_count[['price']]
brooklyn_hotel_grouping_count.rename(columns={'price':'price_bin_count'}, inplace=True)
brooklyn_hotel_grouping = pd.merge(brooklyn_hotel_grouping_mean,brooklyn_hotel_grouping_count, how = 'left', on= 'price_bin')

# %%
sns.set()
fig, axes = plt.subplots(2, 2)
sns.lineplot(x = brooklyn_hotel_grouping.index, y = 'price_bin_count', data=brooklyn_hotel_grouping,ax=axes[0,0])
sns.lineplot(x = brooklyn_hotel_grouping.index, y = 'availability_365', data=brooklyn_hotel_grouping,ax=axes[0,1])
sns.lineplot(x = brooklyn_hotel_grouping.index, y = 'annual_revenue', data=brooklyn_hotel_grouping,ax=axes[1,0])
# Out:
# <AxesSubplot:xlabel='price_bin', ylabel='annual_revenue'>

# %%
brooklyn_shared_grouping_mean =  brooklyn_shared.groupby('price_bin').mean()
brooklyn_shared_grouping_count = brooklyn_shared.groupby('price_bin').count()
brooklyn_shared_grouping_count = brooklyn_shared_grouping_count[['price']]
brooklyn_shared_grouping_count.rename(columns={'price':'price_bin_count'}, inplace=True)
brooklyn_shared_grouping = pd.merge(brooklyn_hotel_grouping_mean,brooklyn_hotel_grouping_count, how = 'left', on= 'price_bin')

# %%
sns.set()
fig, axes = plt.subplots(2, 2)
sns.lineplot(x = brooklyn_shared_grouping.index, y = 'price_bin_count', data=brooklyn_shared_grouping,ax=axes[0,0])
sns.lineplot(x = brooklyn_shared_grouping.index, y = 'availability_365', data=brooklyn_shared_grouping,ax=axes[0,1])
sns.lineplot(x = brooklyn_shared_grouping.index, y = 'annual_revenue', data=brooklyn_shared_grouping,ax=axes[1,0])
# Out:
# <AxesSubplot:xlabel='price_bin', ylabel='annual_revenue'>

# %%
manhattan_home_grouping_mean =  manhattan_home.groupby('price_bin').mean()
manhattan_home_grouping_count = manhattan_home.groupby('price_bin').count()
manhattan_home_grouping_count = manhattan_home_grouping_count[['price']]
manhattan_home_grouping_count.rename(columns={'price':'price_bin_count'}, inplace=True)
manhattan_home_grouping = pd.merge(manhattan_home_grouping_mean,manhattan_home_grouping_count, how = 'left', on= 'price_bin')

# %%
sns.set()
fig, axes = plt.subplots(2, 2)
sns.lineplot(x = manhattan_home_grouping.index, y = 'price_bin_count', data=manhattan_home_grouping,ax=axes[0,0])
sns.lineplot(x = manhattan_home_grouping.index, y = 'availability_365', data=manhattan_home_grouping,ax=axes[0,1])
sns.lineplot(x = manhattan_home_grouping.index, y = 'annual_revenue', data=manhattan_home_grouping,ax=axes[1,0])
# Out:
# <AxesSubplot:xlabel='price_bin', ylabel='annual_revenue'>

# %%
manhattan_private_grouping_mean =  manhattan_private.groupby('price_bin').mean()
manhattan_private_grouping_count = manhattan_private.groupby('price_bin').count()
manhattan_private_grouping_count = manhattan_private_grouping_count[['price']]
manhattan_private_grouping_count.rename(columns={'price':'price_bin_count'}, inplace=True)
manhattan_private_grouping = pd.merge(manhattan_private_grouping_mean,manhattan_private_grouping_count, how = 'left', on= 'price_bin')

# %%
sns.set()
fig, axes = plt.subplots(2, 2)
sns.lineplot(x = manhattan_private_grouping.index, y = 'price_bin_count', data=manhattan_private_grouping,ax=axes[0,0])
sns.lineplot(x = manhattan_private_grouping.index, y = 'availability_365', data=manhattan_private_grouping,ax=axes[0,1])
sns.lineplot(x = manhattan_private_grouping.index, y = 'annual_revenue', data=manhattan_private_grouping,ax=axes[1,0])
# Out:
# <AxesSubplot:xlabel='price_bin', ylabel='annual_revenue'>

# %%
manhattan_hotel_grouping_mean =  manhattan_hotel.groupby('price_bin').mean()
manhattan_hotel_grouping_count = manhattan_hotel.groupby('price_bin').count()
manhattan_hotel_grouping_count = manhattan_hotel_grouping_count[['price']]
manhattan_hotel_grouping_count.rename(columns={'price':'price_bin_count'}, inplace=True)
manhattan_hotel_grouping = pd.merge(manhattan_hotel_grouping_mean,manhattan_hotel_grouping_count, how = 'left', on= 'price_bin')

# %%
sns.set()
fig, axes = plt.subplots(2, 2)
sns.lineplot(x = manhattan_hotel_grouping.index, y = 'price_bin_count', data=manhattan_hotel_grouping,ax=axes[0,0])
sns.lineplot(x = manhattan_hotel_grouping.index, y = 'availability_365', data=manhattan_hotel_grouping,ax=axes[0,1])
sns.lineplot(x = manhattan_hotel_grouping.index, y = 'annual_revenue', data=manhattan_hotel_grouping,ax=axes[1,0])
# Out:
# <AxesSubplot:xlabel='price_bin', ylabel='annual_revenue'>

# %%
manhattan_shared_grouping_mean =  manhattan_shared.groupby('price_bin').mean()
manhattan_shared_grouping_count = manhattan_shared.groupby('price_bin').count()
manhattan_shared_grouping_count = manhattan_shared_grouping_count[['price']]
manhattan_shared_grouping_count.rename(columns={'price':'price_bin_count'}, inplace=True)
manhattan_shared_grouping = pd.merge(manhattan_shared_grouping_mean,manhattan_shared_grouping_count, how = 'left', on= 'price_bin')

# %%
sns.set()
fig, axes = plt.subplots(2, 2)
sns.lineplot(x = manhattan_shared_grouping.index, y = 'price_bin_count', data=manhattan_shared_grouping,ax=axes[0,0])
sns.lineplot(x = manhattan_shared_grouping.index, y = 'availability_365', data=manhattan_shared_grouping,ax=axes[0,1])
sns.lineplot(x = manhattan_shared_grouping.index, y = 'annual_revenue', data=manhattan_shared_grouping,ax=axes[1,0])
# Out:
# <AxesSubplot:xlabel='price_bin', ylabel='annual_revenue'>

# %%
sns.lineplot(x = manhattan_private_grouping.index, y = 'availability_365', data=manhattan_private_grouping)
# Out:
# <AxesSubplot:xlabel='price_bin', ylabel='availability_365'>

# %%
sns.lineplot(x = manhattan_private_grouping.index, y = 'annual_revenue', data=manhattan_private_grouping)
# Out:
# <AxesSubplot:xlabel='price_bin', ylabel='annual_revenue'>

# %%
temp = manhattan_private_grouping.reset_index()

# %%
temp['price_bin'] = temp['price_bin'].astype(int)

# %%
temp[temp['price_bin']<160]
# Out:
#    price_bin       price  minimum_nights  number_of_reviews  \
# 0          0         NaN             NaN                NaN
# 1         20   34.714286        8.500000          18.142857
# 2         40   51.242647        5.051471          41.286765
# 3         60   70.299663        3.942761          44.595960
# 4         80   89.524664        3.208520          52.145740
# 5        100  108.206897        2.727011          54.617816
# 6        120  128.020202        3.067340          47.346801
# 7        140  149.582418        3.274725          53.115385
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                NaN                             NaN               NaN
# 1           0.750000                       15.285714          8.071429
# 2           1.286364                        1.933824         72.441176
# 3           1.546776                        3.649832        114.575758
# 4           2.044264                        5.724215        142.596413
# 5           2.341765                        6.189655        148.485632
# 6           2.084981                        9.909091        154.188552
# 7           1.935455                        3.615385        156.835165
#
#    number_of_reviews_ltm         pps  annual_revenue  log_price   log_pps  \
# 0                    NaN         NaN             NaN        NaN       NaN
# 1               1.642857  307.571429    12378.785714   3.540411  5.095138
# 2               6.257353  256.242647    14896.919118   3.930841  5.020164
# 3              11.003367  277.983165    17514.801347   4.249436  5.191424
# 4              16.757848  286.038117    19944.748879   4.492062  5.314009
# 5              20.491379  295.511494    23340.206897   4.682256  5.350973
# 6              16.468013  392.151515    26953.225589   4.851188  5.697318
# 7              13.659341  488.939560    31194.313187   5.007237  5.808998
#
#    is_budget  is_luxury  price_bin_count
# 0        NaN        NaN                0
# 1   0.857143   0.142857               14
# 2   0.919118   0.080882              136
# 3   0.932660   0.067340              297
# 4   0.943946   0.056054              446
# 5   0.959770   0.040230              348
# 6   0.905724   0.094276              297
# 7   0.906593   0.093407              182

# %%
brooklyn_price_bin_grouping_mean = brooklyn.groupby('price_bin').mean()
brooklyn_price_bin_grouping_count = brooklyn.groupby('price_bin').count()

manhattan_price_bin_grouping_mean = manhattan.groupby('price_bin').mean()
manhattan_price_bin_grouping_count = manhattan.groupby('price_bin').count()

queens_price_bin_grouping_mean = queens.groupby('price_bin').mean()
queens_price_bin_grouping_count = queens.groupby('price_bin').count()

bronx_price_bin_grouping_mean = bronx.groupby('price_bin').mean()
bronx_price_bin_grouping_count = bronx.groupby('price_bin').count()

staten_island_price_bin_grouping_mean = staten_island.groupby('price_bin').mean()
staten_island_price_bin_grouping_count = staten_island.groupby('price_bin').count()

# %%
brooklyn_price_bin_grouping_count = brooklyn_price_bin_grouping_count[['price']]
brooklyn_price_bin_grouping_count.rename(columns={'price':'price_bin_count'}, inplace=True)
brooklyn_price_bin_grouping = pd.merge(brooklyn_price_bin_grouping_mean,brooklyn_price_bin_grouping_count, how = 'left', on= 'price_bin')

manhattan_price_bin_grouping_count = manhattan_price_bin_grouping_count[['price']]
manhattan_price_bin_grouping_count.rename(columns={'price':'price_bin_count'}, inplace=True)
manhattan_price_bin_grouping = pd.merge(manhattan_price_bin_grouping_mean,manhattan_price_bin_grouping_count, how = 'left', on= 'price_bin')

queens_price_bin_grouping_count = queens_price_bin_grouping_count[['price']]
queens_price_bin_grouping_count.rename(columns={'price':'price_bin_count'}, inplace=True)
queens_price_bin_grouping = pd.merge(queens_price_bin_grouping_mean,queens_price_bin_grouping_count, how = 'left', on= 'price_bin')

bronx_price_bin_grouping_count = bronx_price_bin_grouping_count[['price']]
bronx_price_bin_grouping_count.rename(columns={'price':'price_bin_count'}, inplace=True)
bronx_price_bin_grouping = pd.merge(bronx_price_bin_grouping_mean,bronx_price_bin_grouping_count, how = 'left', on= 'price_bin')

staten_island_price_bin_grouping_count = staten_island_price_bin_grouping_count[['price']]
staten_island_price_bin_grouping_count.rename(columns={'price':'price_bin_count'}, inplace=True)
staten_island_price_bin_grouping = pd.merge(staten_island_price_bin_grouping_mean,staten_island_price_bin_grouping_count, how = 'left', on= 'price_bin')

brooklyn_price_bin_grouping
# Out:
#                  price  minimum_nights  number_of_reviews  reviews_per_month  \
# price_bin
# 0                  NaN             NaN                NaN                NaN
# 20           34.058252        5.601942          28.417476           1.128554
# 40           50.227612        4.498134          32.052239           1.340315
# 60           69.349106        3.799159          36.924290           1.787743
# 80           89.224429        3.533267          47.672294           1.863804
# ...                ...             ...                ...                ...
# 1900       1900.000000        1.000000           0.000000                NaN
# 1920               NaN             NaN                NaN                NaN
# 1940               NaN             NaN                NaN                NaN
# 1960               NaN             NaN                NaN                NaN
# 1980               NaN             NaN                NaN                NaN
#
#            calculated_host_listings_count  availability_365  \
# price_bin
# 0                                     NaN               NaN
# 20                               2.902913         81.844660
# 40                               5.242537        107.332090
# 60                               6.029443        167.920084
# 80                               2.884806        165.851043
# ...                                   ...               ...
# 1900                            12.000000        365.000000
# 1920                                  NaN               NaN
# 1940                                  NaN               NaN
# 1960                                  NaN               NaN
# 1980                                  NaN               NaN
#
#            number_of_reviews_ltm          pps  annual_revenue  log_price  \
# price_bin
# 0                            NaN          NaN             NaN        NaN
# 20                      7.058252   189.669903     9550.689320   3.520070
# 40                     10.598881   224.072761    12832.658582   3.910090
# 60                     13.239748   260.363828    13636.597266   4.235522
# 80                     15.222443   314.965243    17741.502483   4.488772
# ...                          ...          ...             ...        ...
# 1900                    0.000000  1900.000000        0.000000   7.549609
# 1920                         NaN          NaN             NaN        NaN
# 1940                         NaN          NaN             NaN        NaN
# 1960                         NaN          NaN             NaN        NaN
# 1980                         NaN          NaN             NaN        NaN
#
#             log_pps  is_budget  is_luxury  price_bin_count
# price_bin
# 0               NaN        NaN        NaN                0
# 20         4.718953   0.951456   0.048544              103
# 40         4.930679   0.938433   0.061567              536
# 60         5.140749   0.931651   0.068349              951
# 80         5.357417   0.936445   0.063555             1007
# ...             ...        ...        ...              ...
# 1900       7.549609   0.000000   1.000000                1
# 1920            NaN        NaN        NaN                0
# 1940            NaN        NaN        NaN                0
# 1960            NaN        NaN        NaN                0
# 1980            NaN        NaN        NaN                0
#
# [100 rows x 14 columns]

# %%
sns.lineplot(x = brooklyn_price_bin_grouping.index, y = 'price_bin_count', data=brooklyn_price_bin_grouping)
plt.title('Counts for Each Price Bin in Brooklyn')
plt.xlabel('Price Bin')
plt.ylabel('Price Bin Count')
# Out:
# Text(0, 0.5, 'Price Bin Count')

# %%
sns.lineplot(x = brooklyn_price_bin_grouping.index, y = 'availability_365', data=brooklyn_price_bin_grouping)
# Out:
# <AxesSubplot:xlabel='price_bin', ylabel='availability_365'>

# %%
sns.lineplot(x = brooklyn_price_bin_grouping.index, y = 'annual_revenue', data=brooklyn_price_bin_grouping)
# Out:
# <AxesSubplot:xlabel='price_bin', ylabel='annual_revenue'>

# %%
sns.lineplot(x = manhattan_price_bin_grouping.index, y = 'price_bin_count', data=manhattan_price_bin_grouping)
plt.title('Counts for Each Price Bin in Manhattan')
plt.xlabel('Price Bin')
plt.ylabel('Price Bin Count')
# Out:
# Text(0, 0.5, 'Price Bin Count')

# %%
sns.lineplot(x = manhattan_price_bin_grouping.index, y = 'availability_365', data=manhattan_price_bin_grouping)
# Out:
# <AxesSubplot:xlabel='price_bin', ylabel='availability_365'>

# %%
sns.lineplot(x = manhattan_price_bin_grouping.index, y = 'annual_revenue', data=manhattan_price_bin_grouping)
# Out:
# <AxesSubplot:xlabel='price_bin', ylabel='annual_revenue'>

# %%
sns.lineplot(x = queens_price_bin_grouping.index, y = 'price_bin_count', data=queens_price_bin_grouping)
plt.title('Counts for Each Price Bin in Queens')
plt.xlabel('Price Bin')
plt.ylabel('Price Bin Count')
# Out:
# Text(0, 0.5, 'Price Bin Count')

# %%
sns.lineplot(x = queens_price_bin_grouping.index, y = 'availability_365', data=queens_price_bin_grouping)
# Out:
# <AxesSubplot:xlabel='price_bin', ylabel='availability_365'>

# %%
sns.lineplot(x = queens_price_bin_grouping.index, y = 'annual_revenue', data=queens_price_bin_grouping)
# Out:
# <AxesSubplot:xlabel='price_bin', ylabel='annual_revenue'>

# %%
sns.lineplot(x = bronx_price_bin_grouping.index, y = 'price_bin_count', data=bronx_price_bin_grouping)
plt.title('Counts for Each Price Bin in the Bronx')
plt.xlabel('Price Bin')
plt.ylabel('Price Bin Count')
# Out:
# Text(0, 0.5, 'Price Bin Count')

# %%
sns.lineplot(x = bronx_price_bin_grouping.index, y = 'availability_365', data=bronx_price_bin_grouping)
# Out:
# <AxesSubplot:xlabel='price_bin', ylabel='availability_365'>

# %%
sns.lineplot(x = bronx_price_bin_grouping.index, y = 'annual_revenue', data=bronx_price_bin_grouping)
# Out:
# <AxesSubplot:xlabel='price_bin', ylabel='annual_revenue'>

# %% [markdown]
# We can see that in the overall lineplot there is a small trend that the availability decreases until you hit the 250 price bin. Looking at the bronx availability, it seems that there may be a higher demand for lower priced listings. This is seem in the annual revenue lineplot where annual revenue is higher at the 200 price bin than the 250 price bin. Also in the availability plot, it shows that the lower price bins are in higher demand. This is different from the trend seens when all of the data points are plotted. Price bins after the $200 have a higher variance meaning there is more risk in listing at that price bin.

# %%
sns.lineplot(x = staten_island_price_bin_grouping.index, y = 'price_bin_count', data=staten_island_price_bin_grouping)
plt.title('Counts for Each Price Bin in Staten Island')
plt.xlabel('Price Bin')
plt.ylabel('Price Bin Count')
# Out:
# Text(0, 0.5, 'Price Bin Count')

# %%
sns.lineplot(x = staten_island_price_bin_grouping.index, y = 'availability_365', data=staten_island_price_bin_grouping)
# Out:
# <AxesSubplot:xlabel='price_bin', ylabel='availability_365'>

# %%
sns.lineplot(x = staten_island_price_bin_grouping.index, y = 'annual_revenue', data=staten_island_price_bin_grouping)
# Out:
# <AxesSubplot:xlabel='price_bin', ylabel='annual_revenue'>

# %%
temp = staten_island_price_bin_grouping.reset_index()

# %%
temp['price_bin'] = temp['price_bin'].astype(int)

# %%
temp[temp['price_bin']>150]
# Out:
#     price_bin        price  minimum_nights  number_of_reviews  \
# 8         160   170.055556        3.166667          48.833333
# 9         180   190.000000        3.142857          25.428571
# 10        200   206.500000        2.500000          32.583333
# 11        220   229.500000        2.750000          41.250000
# 12        240   251.800000        2.000000          24.200000
# ..        ...          ...             ...                ...
# 95       1900          NaN             NaN                NaN
# 96       1920  1929.000000        1.000000          23.000000
# 97       1940          NaN             NaN                NaN
# 98       1960          NaN             NaN                NaN
# 99       1980          NaN             NaN                NaN
#
#     reviews_per_month  calculated_host_listings_count  availability_365  \
# 8            1.996111                        1.888889        214.888889
# 9            3.073333                        3.142857        129.142857
# 10           2.355000                        2.000000        284.750000
# 11           1.645000                        2.875000        214.875000
# 12           2.630000                        2.800000        173.400000
# ..                ...                             ...               ...
# 95                NaN                             NaN               NaN
# 96           0.390000                        2.000000         88.000000
# 97                NaN                             NaN               NaN
# 98                NaN                             NaN               NaN
# 99                NaN                             NaN               NaN
#
#     number_of_reviews_ltm          pps  annual_revenue  log_price   log_pps  \
# 8               18.722222   536.166667    25658.388889   5.135670  6.014003
# 9               16.428571   608.714286    45008.428571   5.246436  6.087308
# 10               8.500000   516.166667    16577.166667   5.329953  6.076519
# 11              13.250000   633.500000    34316.125000   5.435634  6.418158
# 12              22.800000   502.200000    48108.400000   5.528577  6.164188
# ..                    ...          ...             ...        ...       ...
# 95                    NaN          NaN             NaN        NaN       NaN
# 96               4.000000  1929.000000   534333.000000   7.564757  7.564757
# 97                    NaN          NaN             NaN        NaN       NaN
# 98                    NaN          NaN             NaN        NaN       NaN
# 99                    NaN          NaN             NaN        NaN       NaN
#
#     is_budget  is_luxury  price_bin_count
# 8    0.888889   0.111111               18
# 9    0.857143   0.142857                7
# 10   0.916667   0.083333               12
# 11   0.875000   0.125000                8
# 12   1.000000   0.000000                5
# ..        ...        ...              ...
# 95        NaN        NaN                0
# 96   0.000000   1.000000                1
# 97        NaN        NaN                0
# 98        NaN        NaN                0
# 99        NaN        NaN                0
#
# [92 rows x 15 columns]
